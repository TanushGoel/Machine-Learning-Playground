# %% [markdown]
# <a href="https://colab.research.google.com/github/TanushGoel/Machine-Learning-Playground/blob/master/Predicting_Molecular_Properties_Catboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(42)

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
structures = pd.read_csv('structures.csv')
scalar_coupling = pd.read_csv('scalar_coupling_contributions.csv')
magnetic_shielding = pd.read_csv('magnetic_shielding_tensors.csv')
potential_energy = pd.read_csv('potential_energy.csv')
dipole_moments = pd.read_csv('dipole_moments.csv')
mulliken_charges = pd.read_csv('mulliken_charges.csv')
sample_sub = pd.read_csv('sample_submission.csv')

# %%
train.head()
# Out:
#    id     molecule_name  ...  type  scalar_coupling_constant
# 0   0  dsgdb9nsd_000001  ...  1JHC                   84.8076
# 1   1  dsgdb9nsd_000001  ...  2JHH                  -11.2570
# 2   2  dsgdb9nsd_000001  ...  2JHH                  -11.2548
# 3   3  dsgdb9nsd_000001  ...  2JHH                  -11.2543
# 4   4  dsgdb9nsd_000001  ...  1JHC                   84.8074
#
# [5 rows x 6 columns]

# %%
print('Total rows:', len(train))
print('Unique Molecule Names:', len(train.molecule_name.unique()))
print('Unique Coupling Types:', len(train.type.unique()))
# Out:
# Total rows: 4658147
# Unique Molecule Names: 85003
# Unique Coupling Types: 8

# %%
labels = train.scalar_coupling_constant
train = train.drop('scalar_coupling_constant', axis=1)

# %%
test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC

# %%
print('Total rows:', len(test))
print('Unique Molecule Names:', len(test.molecule_name.unique()))
print('Unique Coupling Types:', len(test.type.unique()))
# Out:
# Total rows: 2505542
# Unique Molecule Names: 45772
# Unique Coupling Types: 8

# %%
sample_sub.head()
# Out:
#         id  scalar_coupling_constant
# 0  4658147                         0
# 1  4658148                         0
# 2  4658149                         0
# 3  4658150                         0
# 4  4658151                         0

# %%
scalar_coupling.head()
# Out:
#       molecule_name  atom_index_0  atom_index_1  ...        sd      pso       dso
# 0  dsgdb9nsd_000001             1             0  ...  0.254579  1.25862  0.272010
# 1  dsgdb9nsd_000001             1             2  ...  0.352978  2.85839 -3.433600
# 2  dsgdb9nsd_000001             1             3  ...  0.352944  2.85852 -3.433870
# 3  dsgdb9nsd_000001             1             4  ...  0.352934  2.85855 -3.433930
# 4  dsgdb9nsd_000001             2             0  ...  0.254585  1.25861  0.272013
#
# [5 rows x 8 columns]

# %%
print('Total rows:', len(scalar_coupling))
print('Unique Molecule Names:', len(scalar_coupling.molecule_name.unique()))
print('Unique Coupling Types:', len(scalar_coupling.type.unique()))
# Out:
# Total rows: 4658147
# Unique Molecule Names: 85003
# Unique Coupling Types: 8

# %%
structures.head()
# Out:
#       molecule_name  atom_index atom         x         y         z
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397

# %%
print('Total rows:', len(structures))
print('Unique Molecule Names:', len(structures.molecule_name.unique()))
# Out:
# Total rows: 2358657
# Unique Molecule Names: 130775

# %%
magnetic_shielding.head()
# Out:
#       molecule_name  atom_index        XX  ...      XZ      YZ        ZZ
# 0  dsgdb9nsd_000001           0  195.3150  ... -0.0001  0.0007  195.3170
# 1  dsgdb9nsd_000001           1   31.3410  ...  4.0546 -1.7173   34.0861
# 2  dsgdb9nsd_000001           2   31.5814  ... -4.1476 -1.6036   33.8967
# 3  dsgdb9nsd_000001           3   31.5172  ...  1.2724  1.6951   28.9579
# 4  dsgdb9nsd_000001           4   31.4029  ... -1.1795  1.6260   28.9013
#
# [5 rows x 11 columns]

# %%
print('Total rows:', len(magnetic_shielding))
print('Unique Molecule Names:', len(magnetic_shielding.molecule_name.unique()))
# Out:
# Total rows: 1533537
# Unique Molecule Names: 85003

# %%
potential_energy.head()
# Out:
#       molecule_name  potential_energy
# 0  dsgdb9nsd_000001         -40.52368
# 1  dsgdb9nsd_000002         -56.56025
# 2  dsgdb9nsd_000003         -76.42608
# 3  dsgdb9nsd_000005         -93.42849
# 4  dsgdb9nsd_000007         -79.83869

# %%
print('Total rows:', len(potential_energy))
print('Unique Molecule Names:', len(potential_energy.molecule_name.unique()))
# Out:
# Total rows: 85003
# Unique Molecule Names: 85003

# %%
dipole_moments.head()
# Out:
#       molecule_name       X    Y       Z
# 0  dsgdb9nsd_000001  0.0000  0.0  0.0000
# 1  dsgdb9nsd_000002 -0.0002  0.0  1.6256
# 2  dsgdb9nsd_000003  0.0000  0.0 -1.8511
# 3  dsgdb9nsd_000005  0.0000  0.0 -2.8937
# 4  dsgdb9nsd_000007  0.0000  0.0  0.0000

# %%
print('Total rows:', len(dipole_moments))
print('Unique Molecule Names:', len(dipole_moments.molecule_name.unique()))
# Out:
# Total rows: 85003
# Unique Molecule Names: 85003

# %%
mulliken_charges.head()
# Out:
#       molecule_name  atom_index  mulliken_charge
# 0  dsgdb9nsd_000001           0        -0.535689
# 1  dsgdb9nsd_000001           1         0.133921
# 2  dsgdb9nsd_000001           2         0.133922
# 3  dsgdb9nsd_000001           3         0.133923
# 4  dsgdb9nsd_000001           4         0.133923

# %%
print('Total rows:', len(mulliken_charges))
print('Unique Molecule Names:', len(mulliken_charges.molecule_name.unique()))
# Out:
# Total rows: 1533537
# Unique Molecule Names: 85003

# %%
molecule_names = []
# used structures dataframe because it has all molecule names
for i in structures.molecule_name.unique():
  molecule_names.append(i)

# %%
molecules = pd.DataFrame({
        "molecule_names": molecule_names
    })
molecules.head()
# Out:
#      molecule_names
# 0  dsgdb9nsd_000001
# 1  dsgdb9nsd_000002
# 2  dsgdb9nsd_000003
# 3  dsgdb9nsd_000004
# 4  dsgdb9nsd_000005

# %%
molecule_names_factorized = molecules.molecule_names.factorize()[0]

# %%
molecule_index = dict(zip(molecule_names, molecule_names_factorized))
len(molecule_index)
# Out:
# 130775

# %%
train.type.unique()
# Out:
# array(['1JHC', '2JHH', '1JHN', '2JHN', '2JHC', '3JHH', '3JHC', '3JHN'],
#       dtype=object)

# %%
type_index = {'1JHC':1, '2JHH':2, '1JHN':3, '2JHN':4, '2JHC':5, '3JHH':6, '3JHC':7, '3JHN':8}

# %%
structures.atom.unique()
# Out:
# array(['C', 'H', 'N', 'O', 'F'], dtype=object)

# %%
atom_indices = {'C':1, 'H':2, 'N':3, 'O':4, 'F':5}

# %%
train.molecule_name = train.molecule_name.map(molecule_index)
train.type = train.type.map(type_index)
test.molecule_name = test.molecule_name.map(molecule_index)
test.type = test.type.map(type_index)
scalar_coupling.molecule_name = scalar_coupling.molecule_name.map(molecule_index)
scalar_coupling.type = scalar_coupling.type.map(type_index)
structures.molecule_name = structures.molecule_name.map(molecule_index)
structures.atom = structures.atom.map(atom_indices)
magnetic_shielding.molecule_name = magnetic_shielding.molecule_name.map(molecule_index) 
potential_energy.molecule_name = potential_energy.molecule_name.map(molecule_index) 
dipole_moments.molecule_name = dipole_moments.molecule_name.map(molecule_index)
mulliken_charges.molecule_name = mulliken_charges.molecule_name.map(molecule_index)

# %%
del molecule_index, molecule_names_factorized, molecules, type_index, atom_indices

# %%
def map_structure_info(df, atom_idx):
    df = pd.merge(df, structures, how = 'left',
                  left_on  = ['molecule_name', f'atom_index_{atom_idx}'],
                  right_on = ['molecule_name',  'atom_index'])
    
    df = df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': f'atom_{atom_idx}',
                            'x': f'x_{atom_idx}',
                            'y': f'y_{atom_idx}',
                            'z': f'z_{atom_idx}'})
    return df

# %%
train = map_structure_info(train, 0)
train = map_structure_info(train, 1)

test = map_structure_info(test, 0)
test = map_structure_info(test, 1)

del structures

# %%
#STOP
def map_mulliken_charge(df, atom_idx) :
    df = pd.merge(df, mulliken_charges, how = 'left',
                 left_on=['molecule_name', f'atom_index_{atom_idx}'],
                 right_on=['molecule_name', 'atom_index'])
    df = df.rename(columns={'mulliken_charge':f'mulliken_charge_{atom_idx}'})
    df = df.drop('atom_index', axis=1)
    return df

train = map_mulliken_charge(train, 0)
train = map_mulliken_charge(train, 1)

del mulliken_charges

# %%
train = train.merge(potential_energy, on="molecule_name", how='inner')
del potential_energy

# %%
dipole_moment = np.sqrt(dipole_moments['X'] ** 2 + dipole_moments['Y'] ** 2 + dipole_moments['Z'] ** 2)
dipole_moments['dipole_moment'] = dipole_moment
dipole_moments = dipole_moments.drop(['X','Y','Z'], axis=1)
train = train.merge(dipole_moments, on='molecule_name', how='inner')
del dipole_moment, dipole_moments

# %%
train['fc'] = scalar_coupling.fc
train['sd'] = scalar_coupling.sd
train['pso'] = scalar_coupling.pso
train['dso'] = scalar_coupling.dso

# %%
#START
train_p_0 = train[['x_0', 'y_0', 'z_0']].values
train_p_1 = train[['x_1', 'y_1', 'z_1']].values

train['dist'] = np.linalg.norm(train_p_0 - train_p_1, axis=1)


test_p_0 = test[['x_0', 'y_0', 'z_0']].values
test_p_1 = test[['x_1', 'y_1', 'z_1']].values

test['dist'] = np.linalg.norm(test_p_0 - test_p_1, axis=1)

# %%
train['dist_x'] = (train['x_0'] - train['x_1']) ** 2
train['dist_y'] = (train['y_0'] - train['y_1']) ** 2
train['dist_z'] = (train['z_0'] - train['z_1']) ** 2

test['dist_x'] = (test['x_0'] - test['x_1']) ** 2
test['dist_y'] = (test['y_0'] - test['y_1']) ** 2
test['dist_z'] = (test['z_0'] - test['z_1']) ** 2

# %%
train["min_distance_0"] = train.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('min')
train["min_distance_1"] = train.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('min')

test["min_distance_0"] = test.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('min')
test["min_distance_1"] = test.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('min')

# %%
train = reduce_mem_usage(train)

# %%
test = reduce_mem_usage(test)

# %%
def create_features(df):
  df["distance_0"]=((df['x_0']-df['dist_x'])**2+(df['y_0']-df['dist_y'])**2+(df['z_0']-df['dist_z'])**2)**(1/2)
  df["distance_1"]=((df['x_1']-df['dist_x'])**2+(df['y_1']-df['dist_y'])**2+(df['z_1']-df['dist_z'])**2)**(1/2)
  df["vec_0_x"]=(df['x_0']-df['dist_x'])/(df["distance_0"]+1e-10)
  df["vec_0_y"]=(df['y_0']-df['dist_y'])/(df["distance_0"]+1e-10)
  df["vec_0_z"]=(df['z_0']-df['dist_z'])/(df["distance_0"]+1e-10)
  df["vec_1_x"]=(df['x_1']-df['dist_x'])/(df["distance_1"]+1e-10)
  df["vec_1_y"]=(df['y_1']-df['dist_y'])/(df["distance_1"]+1e-10)
  df["vec_1_z"]=(df['z_1']-df['dist_z'])/(df["distance_1"]+1e-10)
  df["vec_x"]=(df['x_1']-df['x_0'])/(df["dist"]+1e-10)
  df["vec_y"]=(df['y_1']-df['y_0'])/(df["dist"]+1e-10)
  df["vec_z"]=(df['z_1']-df['z_0'])/(df["dist"]+1e-10)
  df["cos_0_1"]=df["vec_0_x"]*df["vec_1_x"]+df["vec_0_y"]*df["vec_1_y"]+df["vec_0_z"]*df["vec_1_z"]
  df["cos_0"]=df["vec_0_x"]*df["vec_x"]+df["vec_0_y"]*df["vec_y"]+df["vec_0_z"]*df["vec_z"]
  df["cos_1"]=df["vec_1_x"]*df["vec_x"]+df["vec_1_y"]*df["vec_y"]+df["vec_1_z"]*df["vec_z"]
  df = df.drop('vec_0_x', axis=1)
  df = df.drop('vec_0_y', axis=1)
  df = df.drop('vec_0_z', axis=1)
  df = df.drop('vec_1_x', axis=1)
  df = df.drop('vec_1_y', axis=1)
  df = df.drop('vec_1_z', axis=1)
  df = df.drop('vec_x', axis=1)
  df = df.drop('vec_y', axis=1)
  df = df.drop('vec_z', axis=1)
  
  return df

train = create_features(train)
test = create_features(test)

# %%
train = reduce_mem_usage(train)

# %%
test = reduce_mem_usage(test)

# %%
def create_more_features(df):
  
  
    df['dist_to_type_mean'] = df['dist'] / df.groupby('type')['dist'].transform('mean')
    
    df['molecule_couples'] = df.groupby('molecule_name')['id'].transform('count')
    
    df['molecule_dist_mean'] = df.groupby('molecule_name')['dist'].transform('mean')
    df['molecule_dist_mean_div'] = df['molecule_dist_mean'] / df['dist']
    #df = df.drop('molecule_dist_mean', axis=1)
    
    df['molecule_dist_min'] = df.groupby('molecule_name')['dist'].transform('min')
    df['molecule_dist_max'] = df.groupby('molecule_name')['dist'].transform('max')
    
    df[f'molecule_type_dist_std'] = df.groupby(['molecule_name', 'type'])['dist'].transform('std')
    df[f'molecule_type_dist_std_diff'] = df[f'molecule_type_dist_std'] - df['dist']
    
    df['molecule_type_dist_mean'] = df.groupby(['molecule_name', 'type'])['dist'].transform('mean')
    df['molecule_type_dist_mean_div'] = df['molecule_type_dist_mean'] / df['dist']
    #df = df.drop('molecule_type_dist_mean', axis=1)
    
    df['molecule_type_dist_max'] = df.groupby(['molecule_name', 'type'])['dist'].transform('max')
    df['molecule_type_dist_min'] = df.groupby(['molecule_name', 'type'])['dist'].transform('min')
    
    df['atom_0_couples_count'] = df.groupby(['molecule_name', 'atom_index_0'])['id'].transform('count')
    df['atom_1_couples_count'] = df.groupby(['molecule_name', 'atom_index_1'])['id'].transform('count')
    
    df['molecule_atom_index_0_dist_mean'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('mean')
    df['molecule_atom_index_0_dist_mean_div'] = df['molecule_atom_index_0_dist_mean'] / df['dist']
    #df = df.drop('molecule_atom_index_0_dist_mean', axis=1)
    
    df['molecule_atom_index_0_dist_max'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('max')
    df['molecule_atom_index_0_dist_max_div'] = df['molecule_atom_index_0_dist_max'] / df['dist']
    #df = df.drop('molecule_atom_index_0_dist_max', axis=1)
    
    df['molecule_atom_index_0_dist_min'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('min')
    df['molecule_atom_index_0_dist_min_div'] = df['molecule_atom_index_0_dist_min'] / df['dist']
    #df = df.drop('molecule_atom_index_0_dist_min', axis=1)
    
    df['molecule_atom_index_1_dist_mean'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('mean')
    df['molecule_atom_index_1_dist_mean_div'] = df['molecule_atom_index_1_dist_mean'] / df['dist']
    #df = df.drop('molecule_atom_index_1_dist_mean', axis=1)
    
    df['molecule_atom_index_1_dist_max'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('max')
    df['molecule_atom_index_1_dist_max_div'] = df['molecule_atom_index_1_dist_max'] / df['dist']
    #df = df.drop('molecule_atom_index_1_dist_max', axis=1)
    
    df['molecule_atom_index_1_dist_min'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('min')
    df['molecule_atom_index_1_dist_min_div'] = df['molecule_atom_index_1_dist_min'] / df['dist']
    #df = df.drop('molecule_atom_index_1_dist_min', axis=1)

    df[f'molecule_atom_index_0_dist_std'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('std')
    df[f'molecule_atom_index_0_dist_std_diff'] = df[f'molecule_atom_index_0_dist_std'] - df['dist']
    df[f'molecule_atom_index_0_dist_std_div'] = df[f'molecule_atom_index_0_dist_std'] / df['dist']
    
    df[f'molecule_atom_index_1_dist_std'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('std')
    df[f'molecule_atom_index_1_dist_std_diff'] = df[f'molecule_atom_index_1_dist_std'] - df['dist']
    df[f'molecule_atom_index_1_dist_std_div'] = df[f'molecule_atom_index_1_dist_std'] / df['dist']
    
    df[f'molecule_atom_index_0_x_1_std'] = df.groupby(['molecule_name', 'atom_index_0'])['x_1'].transform('std')
    df[f'molecule_atom_index_0_y_1_std'] = df.groupby(['molecule_name', 'atom_index_0'])['y_1'].transform('std')
    df[f'molecule_atom_index_0_z_1_std'] = df.groupby(['molecule_name', 'atom_index_0'])['z_1'].transform('std')
    
    df[f'molecule_atom_1_dist_std'] = df.groupby(['molecule_name', 'atom_1'])['dist'].transform('std')
    df[f'molecule_atom_1_dist_std_diff'] = df[f'molecule_atom_1_dist_std'] - df['dist']
    
    return df
  
train = create_more_features(train)
test = create_more_features(test)

# %%
train = reduce_mem_usage(train)

# %%
test = reduce_mem_usage(test)

# %%
train = train.drop(['molecule_name', 'id'], axis=1)
test = test.drop(['molecule_name', 'id'], axis=1)

# %%
train.head()
# Out:
#    atom_index_0  ...  molecule_atom_1_dist_std_diff
# 0             1  ...                      -1.091797
# 1             1  ...                      -1.783203
# 2             1  ...                      -1.783203
# 3             1  ...                      -1.783203
# 4             2  ...                      -1.091797
#
# [5 rows x 59 columns]

# %%
train.isnull().sum()
# Out:
# atom_index_0                                0
# atom_index_1                                0
# type                                        0
# atom_0                                      0
# x_0                                         0
# y_0                                         0
# z_0                                         0
# atom_1                                      0
# x_1                                         0
# y_1                                         0
# z_1                                         0
# dist                                        0
# dist_x                                      0
# dist_y                                      0
# dist_z                                      0
# min_distance_0                              0
# min_distance_1                              0
# distance_0                                  0
# distance_1                                  0
# cos_0_1                                     0
# cos_0                                       0
# cos_1                                       0
# dist_to_type_mean                           0
# molecule_couples                            0
# molecule_dist_mean                          0
# molecule_dist_mean_div                      0
# molecule_dist_min                           0
# molecule_dist_max                           0
# molecule_type_dist_std                  48394
# molecule_type_dist_std_diff             48394
# molecule_type_dist_mean                     0
# molecule_type_dist_mean_div                 0
# molecule_type_dist_max                      0
# molecule_type_dist_min                      0
# atom_0_couples_count                        0
# atom_1_couples_count                        0
# molecule_atom_index_0_dist_mean             0
# molecule_atom_index_0_dist_mean_div         0
# molecule_atom_index_0_dist_max              0
# molecule_atom_index_0_dist_max_div          0
# molecule_atom_index_0_dist_min              0
# molecule_atom_index_0_dist_min_div          0
# molecule_atom_index_1_dist_mean             0
# molecule_atom_index_1_dist_mean_div         0
# molecule_atom_index_1_dist_max              0
# molecule_atom_index_1_dist_max_div          0
# molecule_atom_index_1_dist_min              0
# molecule_atom_index_1_dist_min_div          0
# molecule_atom_index_0_dist_std              4
# molecule_atom_index_0_dist_std_diff         4
# molecule_atom_index_0_dist_std_div          4
# molecule_atom_index_1_dist_std         284076
# molecule_atom_index_1_dist_std_diff    284076
# molecule_atom_index_1_dist_std_div     284076
# molecule_atom_index_0_x_1_std               4
# molecule_atom_index_0_y_1_std               4
# molecule_atom_index_0_z_1_std               4
# molecule_atom_1_dist_std                 4699
# molecule_atom_1_dist_std_diff            4699
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(train, labels, test_size=0.0000575, random_state=1)
del train
del labels

# %%
print('Train:', len(y_train))
print('Valid:', len(y_valid))
# Out:
# Train: 4657879
# Valid: 268

# %%
# !pip install catboost
from catboost import Pool, CatBoostRegressor
# Out:
# Collecting catboost
#   Downloading https://files.pythonhosted.org/packages/5a/8a/a867c35770291646b085e9248814eb32dbe2aa824715b08e40cd92d0a83e/catboost-0.15.1-cp36-none-manylinux1_x86_64.whl (61.0MB)
#      |████████████████████████████████| 61.1MB 1.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from catboost) (1.12.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from catboost) (1.16.4)
# Requirement already satisfied: pandas>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from catboost) (0.24.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from catboost) (0.10.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.1->catboost) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.1->catboost) (2018.9)
# Installing collected packages: catboost
# Successfully installed catboost-0.15.1

# %%
cat = CatBoostRegressor(loss_function='RMSE', boosting_type='Plain', bootstrap_type='Bernoulli', eval_metric='R2', 
                        subsample=0.725, od_type="Iter", iterations=3250, use_best_model=True, random_state=42)
train_pool = Pool(X_train, y_train)
del X_train
del y_train
cat.fit(train_pool, eval_set=(X_valid, y_valid), early_stopping_rounds=100, verbose=1)
cat.best_score_
# Out:
# 0:	learn: 0.0484580	test: 0.0466074	best: 0.0466074 (0)	total: 2.44s	remaining: 2h 12m 13s
# 1:	learn: 0.0949458	test: 0.0914801	best: 0.0914801 (1)	total: 4.73s	remaining: 2h 7m 57s
# 2:	learn: 0.1395327	test: 0.1345679	best: 0.1345679 (2)	total: 7s	remaining: 2h 6m 15s
# 3:	learn: 0.1822591	test: 0.1759311	best: 0.1759311 (3)	total: 9.17s	remaining: 2h 4m 2s
# 4:	learn: 0.2231494	test: 0.2156781	best: 0.2156781 (4)	total: 11.4s	remaining: 2h 3m 16s
# 5:	learn: 0.2622448	test: 0.2537818	best: 0.2537818 (5)	total: 13.5s	remaining: 2h 1m 51s
# 6:	learn: 0.2995814	test: 0.2899945	best: 0.2899945 (6)	total: 15.7s	remaining: 2h 1m 26s
# 7:	learn: 0.3353106	test: 0.3246061	best: 0.3246061 (7)	total: 18s	remaining: 2h 1m 38s
# 8:	learn: 0.3694260	test: 0.3580760	best: 0.3580760 (8)	total: 20.2s	remaining: 2h 56s
# 9:	learn: 0.4018702	test: 0.3897080	best: 0.3897080 (9)	total: 22.4s	remaining: 2h 48s
# 10:	learn: 0.4328212	test: 0.4201204	best: 0.4201204 (10)	total: 24.5s	remaining: 2h 13s
# 11:	learn: 0.4622492	test: 0.4489095	best: 0.4489095 (11)	total: 26.7s	remaining: 2h
# 12:	learn: 0.4902999	test: 0.4761628	best: 0.4761628 (12)	total: 28.8s	remaining: 1h 59m 36s
# 13:	learn: 0.5169585	test: 0.5025674	best: 0.5025674 (13)	total: 31.1s	remaining: 1h 59m 40s
# 14:	learn: 0.5423518	test: 0.5270590	best: 0.5270590 (14)	total: 33.2s	remaining: 1h 59m 18s
# 15:	learn: 0.5665111	test: 0.5505759	best: 0.5505759 (15)	total: 35.4s	remaining: 1h 59m 6s
# 16:	learn: 0.5893323	test: 0.5731431	best: 0.5731431 (16)	total: 37.4s	remaining: 1h 58m 33s
# 17:	learn: 0.6111222	test: 0.5943850	best: 0.5943850 (17)	total: 39.6s	remaining: 1h 58m 25s
# 18:	learn: 0.6316992	test: 0.6146262	best: 0.6146262 (18)	total: 41.9s	remaining: 1h 58m 52s
# 19:	learn: 0.6512686	test: 0.6338729	best: 0.6338729 (19)	total: 44s	remaining: 1h 58m 32s
# 20:	learn: 0.6697960	test: 0.6520631	best: 0.6520631 (20)	total: 46.3s	remaining: 1h 58m 41s
# 21:	learn: 0.6873731	test: 0.6693588	best: 0.6693588 (21)	total: 48.5s	remaining: 1h 58m 41s
# 22:	learn: 0.7040421	test: 0.6857830	best: 0.6857830 (22)	total: 50.7s	remaining: 1h 58m 34s
# 23:	learn: 0.7198419	test: 0.7013826	best: 0.7013826 (23)	total: 52.8s	remaining: 1h 58m 22s
# 24:	learn: 0.7347343	test: 0.7163348	best: 0.7163348 (24)	total: 55.2s	remaining: 1h 58m 36s
# 25:	learn: 0.7488349	test: 0.7303186	best: 0.7303186 (25)	total: 57.3s	remaining: 1h 58m 28s
# 26:	learn: 0.7621921	test: 0.7433969	best: 0.7433969 (26)	total: 59.4s	remaining: 1h 58m 13s
# 27:	learn: 0.7748454	test: 0.7558423	best: 0.7558423 (27)	total: 1m 1s	remaining: 1h 58m 6s
# 28:	learn: 0.7867569	test: 0.7676381	best: 0.7676381 (28)	total: 1m 3s	remaining: 1h 57m 51s
# 29:	learn: 0.7980649	test: 0.7787991	best: 0.7787991 (29)	total: 1m 5s	remaining: 1h 57m 49s
# 30:	learn: 0.8087190	test: 0.7893722	best: 0.7893722 (30)	total: 1m 7s	remaining: 1h 57m 35s
# 31:	learn: 0.8188481	test: 0.7992536	best: 0.7992536 (31)	total: 1m 10s	remaining: 1h 57m 46s
# 32:	learn: 0.8283956	test: 0.8087718	best: 0.8087718 (32)	total: 1m 12s	remaining: 1h 57m 37s
# 33:	learn: 0.8373932	test: 0.8176437	best: 0.8176437 (33)	total: 1m 14s	remaining: 1h 57m 33s
# 34:	learn: 0.8459199	test: 0.8265856	best: 0.8265856 (34)	total: 1m 16s	remaining: 1h 57m 28s
# 35:	learn: 0.8539351	test: 0.8348203	best: 0.8348203 (35)	total: 1m 18s	remaining: 1h 57m 13s
# 36:	learn: 0.8615248	test: 0.8423680	best: 0.8423680 (36)	total: 1m 21s	remaining: 1h 57m 15s
# 37:	learn: 0.8686922	test: 0.8497971	best: 0.8497971 (37)	total: 1m 23s	remaining: 1h 57m 7s
# 38:	learn: 0.8754578	test: 0.8567953	best: 0.8567953 (38)	total: 1m 25s	remaining: 1h 56m 54s
# 39:	learn: 0.8818254	test: 0.8633325	best: 0.8633325 (39)	total: 1m 27s	remaining: 1h 56m 47s
# 40:	learn: 0.8878380	test: 0.8694719	best: 0.8694719 (40)	total: 1m 29s	remaining: 1h 56m 39s
# 41:	learn: 0.8935555	test: 0.8755541	best: 0.8755541 (41)	total: 1m 31s	remaining: 1h 56m 45s
# 42:	learn: 0.8989254	test: 0.8809575	best: 0.8809575 (42)	total: 1m 33s	remaining: 1h 56m 46s
# 43:	learn: 0.9039979	test: 0.8862969	best: 0.8862969 (43)	total: 1m 36s	remaining: 1h 56m 49s
# 44:	learn: 0.9087655	test: 0.8912967	best: 0.8912967 (44)	total: 1m 38s	remaining: 1h 56m 39s
# 45:	learn: 0.9132571	test: 0.8959264	best: 0.8959264 (45)	total: 1m 40s	remaining: 1h 56m 44s
# 46:	learn: 0.9174996	test: 0.9002813	best: 0.9002813 (46)	total: 1m 42s	remaining: 1h 56m 44s
# 47:	learn: 0.9214915	test: 0.9043962	best: 0.9043962 (47)	total: 1m 45s	remaining: 1h 56m 48s
# 48:	learn: 0.9252474	test: 0.9082311	best: 0.9082311 (48)	total: 1m 47s	remaining: 1h 56m 54s
# 49:	learn: 0.9287928	test: 0.9118756	best: 0.9118756 (49)	total: 1m 49s	remaining: 1h 56m 59s
# 50:	learn: 0.9321752	test: 0.9155217	best: 0.9155217 (50)	total: 1m 51s	remaining: 1h 57m 1s
# 51:	learn: 0.9353584	test: 0.9187893	best: 0.9187893 (51)	total: 1m 54s	remaining: 1h 57m 1s
# 52:	learn: 0.9383685	test: 0.9221086	best: 0.9221086 (52)	total: 1m 56s	remaining: 1h 57m 1s
# 53:	learn: 0.9412093	test: 0.9251785	best: 0.9251785 (53)	total: 1m 58s	remaining: 1h 57m 1s
# 54:	learn: 0.9438617	test: 0.9279203	best: 0.9279203 (54)	total: 2m	remaining: 1h 57m 3s
# 55:	learn: 0.9463620	test: 0.9305678	best: 0.9305678 (55)	total: 2m 3s	remaining: 1h 56m 57s
# 56:	learn: 0.9487219	test: 0.9331237	best: 0.9331237 (56)	total: 2m 5s	remaining: 1h 56m 51s
# 57:	learn: 0.9509543	test: 0.9354451	best: 0.9354451 (57)	total: 2m 7s	remaining: 1h 56m 46s
# 58:	learn: 0.9530766	test: 0.9377948	best: 0.9377948 (58)	total: 2m 9s	remaining: 1h 56m 50s
# 59:	learn: 0.9550607	test: 0.9399301	best: 0.9399301 (59)	total: 2m 11s	remaining: 1h 56m 40s
# 60:	learn: 0.9569353	test: 0.9419186	best: 0.9419186 (60)	total: 2m 13s	remaining: 1h 56m 33s
# 61:	learn: 0.9586878	test: 0.9438319	best: 0.9438319 (61)	total: 2m 15s	remaining: 1h 56m 30s
# 62:	learn: 0.9603559	test: 0.9455871	best: 0.9455871 (62)	total: 2m 18s	remaining: 1h 56m 25s
# 63:	learn: 0.9619213	test: 0.9473386	best: 0.9473386 (63)	total: 2m 20s	remaining: 1h 56m 37s
# 64:	learn: 0.9634207	test: 0.9490442	best: 0.9490442 (64)	total: 2m 22s	remaining: 1h 56m 42s
# 65:	learn: 0.9648139	test: 0.9505294	best: 0.9505294 (65)	total: 2m 25s	remaining: 1h 56m 40s
# 66:	learn: 0.9661185	test: 0.9519690	best: 0.9519690 (66)	total: 2m 27s	remaining: 1h 56m 54s
# 67:	learn: 0.9673780	test: 0.9534253	best: 0.9534253 (67)	total: 2m 29s	remaining: 1h 56m 53s
# 68:	learn: 0.9685478	test: 0.9547362	best: 0.9547362 (68)	total: 2m 32s	remaining: 1h 56m 52s
# 69:	learn: 0.9696468	test: 0.9560188	best: 0.9560188 (69)	total: 2m 34s	remaining: 1h 56m 46s
# 70:	learn: 0.9706824	test: 0.9571869	best: 0.9571869 (70)	total: 2m 36s	remaining: 1h 56m 50s
# 71:	learn: 0.9716725	test: 0.9582443	best: 0.9582443 (71)	total: 2m 38s	remaining: 1h 56m 37s
# 72:	learn: 0.9725989	test: 0.9592955	best: 0.9592955 (72)	total: 2m 40s	remaining: 1h 56m 28s
# 73:	learn: 0.9734971	test: 0.9604266	best: 0.9604266 (73)	total: 2m 42s	remaining: 1h 56m 28s
# 74:	learn: 0.9743155	test: 0.9613465	best: 0.9613465 (74)	total: 2m 44s	remaining: 1h 56m 24s
# 75:	learn: 0.9751055	test: 0.9622124	best: 0.9622124 (75)	total: 2m 47s	remaining: 1h 56m 22s
# 76:	learn: 0.9758420	test: 0.9630557	best: 0.9630557 (76)	total: 2m 49s	remaining: 1h 56m 31s
# 77:	learn: 0.9765507	test: 0.9638655	best: 0.9638655 (77)	total: 2m 51s	remaining: 1h 56m 30s
# 78:	learn: 0.9772184	test: 0.9647033	best: 0.9647033 (78)	total: 2m 53s	remaining: 1h 56m 24s
# 79:	learn: 0.9778406	test: 0.9654124	best: 0.9654124 (79)	total: 2m 56s	remaining: 1h 56m 25s
# 80:	learn: 0.9784241	test: 0.9661237	best: 0.9661237 (80)	total: 2m 58s	remaining: 1h 56m 29s
# 81:	learn: 0.9789764	test: 0.9667779	best: 0.9667779 (81)	total: 3m 1s	remaining: 1h 56m 32s
# 82:	learn: 0.9795019	test: 0.9674173	best: 0.9674173 (82)	total: 3m 3s	remaining: 1h 56m 23s
# 83:	learn: 0.9800115	test: 0.9679901	best: 0.9679901 (83)	total: 3m 5s	remaining: 1h 56m 29s
# 84:	learn: 0.9804881	test: 0.9685620	best: 0.9685620 (84)	total: 3m 7s	remaining: 1h 56m 25s
# 85:	learn: 0.9809532	test: 0.9692129	best: 0.9692129 (85)	total: 3m 9s	remaining: 1h 56m 26s
# 86:	learn: 0.9813926	test: 0.9698826	best: 0.9698826 (86)	total: 3m 12s	remaining: 1h 56m 29s
# 87:	learn: 0.9817894	test: 0.9703881	best: 0.9703881 (87)	total: 3m 14s	remaining: 1h 56m 24s
# 88:	learn: 0.9821640	test: 0.9708490	best: 0.9708490 (88)	total: 3m 16s	remaining: 1h 56m 22s
# 89:	learn: 0.9825295	test: 0.9712930	best: 0.9712930 (89)	total: 3m 18s	remaining: 1h 56m 24s
# 90:	learn: 0.9828794	test: 0.9716919	best: 0.9716919 (90)	total: 3m 21s	remaining: 1h 56m 22s
# 91:	learn: 0.9832053	test: 0.9720865	best: 0.9720865 (91)	total: 3m 23s	remaining: 1h 56m 26s
# 92:	learn: 0.9835110	test: 0.9724386	best: 0.9724386 (92)	total: 3m 26s	remaining: 1h 56m 33s
# 93:	learn: 0.9838022	test: 0.9727648	best: 0.9727648 (93)	total: 3m 28s	remaining: 1h 56m 36s
# 94:	learn: 0.9840817	test: 0.9731177	best: 0.9731177 (94)	total: 3m 30s	remaining: 1h 56m 29s
# 95:	learn: 0.9843717	test: 0.9735869	best: 0.9735869 (95)	total: 3m 32s	remaining: 1h 56m 26s
# 96:	learn: 0.9846320	test: 0.9740223	best: 0.9740223 (96)	total: 3m 34s	remaining: 1h 56m 22s
# 97:	learn: 0.9848784	test: 0.9743416	best: 0.9743416 (97)	total: 3m 37s	remaining: 1h 56m 20s
# 98:	learn: 0.9851045	test: 0.9746253	best: 0.9746253 (98)	total: 3m 39s	remaining: 1h 56m 15s
# 99:	learn: 0.9853180	test: 0.9749049	best: 0.9749049 (99)	total: 3m 41s	remaining: 1h 56m 15s
# 100:	learn: 0.9855210	test: 0.9751494	best: 0.9751494 (100)	total: 3m 43s	remaining: 1h 56m 18s
# 101:	learn: 0.9857050	test: 0.9753934	best: 0.9753934 (101)	total: 3m 45s	remaining: 1h 56m 12s
# 102:	learn: 0.9858919	test: 0.9756004	best: 0.9756004 (102)	total: 3m 48s	remaining: 1h 56m 13s
# 103:	learn: 0.9860819	test: 0.9760159	best: 0.9760159 (103)	total: 3m 50s	remaining: 1h 56m 5s
# 104:	learn: 0.9862529	test: 0.9762423	best: 0.9762423 (104)	total: 3m 52s	remaining: 1h 56m
# 105:	learn: 0.9864175	test: 0.9764406	best: 0.9764406 (105)	total: 3m 54s	remaining: 1h 55m 57s
# 106:	learn: 0.9865661	test: 0.9766236	best: 0.9766236 (106)	total: 3m 56s	remaining: 1h 56m 1s
# 107:	learn: 0.9867165	test: 0.9768629	best: 0.9768629 (107)	total: 3m 59s	remaining: 1h 55m 56s
# 108:	learn: 0.9868777	test: 0.9771984	best: 0.9771984 (108)	total: 4m 1s	remaining: 1h 55m 47s
# 109:	learn: 0.9870046	test: 0.9773646	best: 0.9773646 (109)	total: 4m 3s	remaining: 1h 55m 48s
# 110:	learn: 0.9871275	test: 0.9775326	best: 0.9775326 (110)	total: 4m 5s	remaining: 1h 55m 41s
# 111:	learn: 0.9872471	test: 0.9776770	best: 0.9776770 (111)	total: 4m 7s	remaining: 1h 55m 45s
# 112:	learn: 0.9873594	test: 0.9778382	best: 0.9778382 (112)	total: 4m 10s	remaining: 1h 55m 43s
# 113:	learn: 0.9874920	test: 0.9781290	best: 0.9781290 (113)	total: 4m 12s	remaining: 1h 55m 36s
# 114:	learn: 0.9875990	test: 0.9783003	best: 0.9783003 (114)	total: 4m 14s	remaining: 1h 55m 38s
# 115:	learn: 0.9876969	test: 0.9784485	best: 0.9784485 (115)	total: 4m 16s	remaining: 1h 55m 39s
# 116:	learn: 0.9877867	test: 0.9785544	best: 0.9785544 (116)	total: 4m 19s	remaining: 1h 55m 35s
# 117:	learn: 0.9878891	test: 0.9788138	best: 0.9788138 (117)	total: 4m 21s	remaining: 1h 55m 28s
# 118:	learn: 0.9879831	test: 0.9790183	best: 0.9790183 (118)	total: 4m 22s	remaining: 1h 55m 17s
# 119:	learn: 0.9880666	test: 0.9791297	best: 0.9791297 (119)	total: 4m 25s	remaining: 1h 55m 13s
# 120:	learn: 0.9881461	test: 0.9792452	best: 0.9792452 (120)	total: 4m 27s	remaining: 1h 55m 11s
# 121:	learn: 0.9882197	test: 0.9793550	best: 0.9793550 (121)	total: 4m 29s	remaining: 1h 55m 13s
# 122:	learn: 0.9882909	test: 0.9794656	best: 0.9794656 (122)	total: 4m 31s	remaining: 1h 55m 13s
# 123:	learn: 0.9883656	test: 0.9795545	best: 0.9795545 (123)	total: 4m 34s	remaining: 1h 55m 14s
# 124:	learn: 0.9884351	test: 0.9796330	best: 0.9796330 (124)	total: 4m 36s	remaining: 1h 55m 8s
# 125:	learn: 0.9884963	test: 0.9797058	best: 0.9797058 (125)	total: 4m 38s	remaining: 1h 54m 57s
# 126:	learn: 0.9885597	test: 0.9798084	best: 0.9798084 (126)	total: 4m 40s	remaining: 1h 54m 49s
# 127:	learn: 0.9886290	test: 0.9800086	best: 0.9800086 (127)	total: 4m 42s	remaining: 1h 54m 44s
# 128:	learn: 0.9886935	test: 0.9800933	best: 0.9800933 (128)	total: 4m 44s	remaining: 1h 54m 41s
# 129:	learn: 0.9887477	test: 0.9801521	best: 0.9801521 (129)	total: 4m 46s	remaining: 1h 54m 35s
# 130:	learn: 0.9888071	test: 0.9802800	best: 0.9802800 (130)	total: 4m 48s	remaining: 1h 54m 36s
# 131:	learn: 0.9888617	test: 0.9804620	best: 0.9804620 (131)	total: 4m 50s	remaining: 1h 54m 31s
# 132:	learn: 0.9889084	test: 0.9805173	best: 0.9805173 (132)	total: 4m 52s	remaining: 1h 54m 21s
# 133:	learn: 0.9889566	test: 0.9805979	best: 0.9805979 (133)	total: 4m 54s	remaining: 1h 54m 18s
# 134:	learn: 0.9890066	test: 0.9807492	best: 0.9807492 (134)	total: 4m 57s	remaining: 1h 54m 15s
# 135:	learn: 0.9890545	test: 0.9808359	best: 0.9808359 (135)	total: 4m 59s	remaining: 1h 54m 9s
# 136:	learn: 0.9891200	test: 0.9810118	best: 0.9810118 (136)	total: 5m 1s	remaining: 1h 54m 4s
# 137:	learn: 0.9891654	test: 0.9810637	best: 0.9810637 (137)	total: 5m 3s	remaining: 1h 54m 4s
# 138:	learn: 0.9892063	test: 0.9811177	best: 0.9811177 (138)	total: 5m 5s	remaining: 1h 53m 59s
# 139:	learn: 0.9892436	test: 0.9811735	best: 0.9811735 (139)	total: 5m 7s	remaining: 1h 53m 54s
# 140:	learn: 0.9892796	test: 0.9812221	best: 0.9812221 (140)	total: 5m 9s	remaining: 1h 53m 53s
# 141:	learn: 0.9893162	test: 0.9812804	best: 0.9812804 (141)	total: 5m 12s	remaining: 1h 53m 50s
# 142:	learn: 0.9893545	test: 0.9813512	best: 0.9813512 (142)	total: 5m 14s	remaining: 1h 53m 43s
# 143:	learn: 0.9893927	test: 0.9813983	best: 0.9813983 (143)	total: 5m 16s	remaining: 1h 53m 45s
# 144:	learn: 0.9894287	test: 0.9814712	best: 0.9814712 (144)	total: 5m 18s	remaining: 1h 53m 38s
# 145:	learn: 0.9894697	test: 0.9815269	best: 0.9815269 (145)	total: 5m 20s	remaining: 1h 53m 42s
# 146:	learn: 0.9895134	test: 0.9817238	best: 0.9817238 (146)	total: 5m 22s	remaining: 1h 53m 37s
# 147:	learn: 0.9895466	test: 0.9817813	best: 0.9817813 (147)	total: 5m 25s	remaining: 1h 53m 35s
# 148:	learn: 0.9895799	test: 0.9818383	best: 0.9818383 (148)	total: 5m 27s	remaining: 1h 53m 35s
# 149:	learn: 0.9896114	test: 0.9818771	best: 0.9818771 (149)	total: 5m 29s	remaining: 1h 53m 31s
# 150:	learn: 0.9896507	test: 0.9820196	best: 0.9820196 (150)	total: 5m 31s	remaining: 1h 53m 24s
# 151:	learn: 0.9896897	test: 0.9822027	best: 0.9822027 (151)	total: 5m 33s	remaining: 1h 53m 20s
# 152:	learn: 0.9897239	test: 0.9822444	best: 0.9822444 (152)	total: 5m 36s	remaining: 1h 53m 22s
# 153:	learn: 0.9897604	test: 0.9823134	best: 0.9823134 (153)	total: 5m 38s	remaining: 1h 53m 22s
# 154:	learn: 0.9897950	test: 0.9824442	best: 0.9824442 (154)	total: 5m 40s	remaining: 1h 53m 16s
# 155:	learn: 0.9898184	test: 0.9824787	best: 0.9824787 (155)	total: 5m 42s	remaining: 1h 53m 14s
# 156:	learn: 0.9898482	test: 0.9825312	best: 0.9825312 (156)	total: 5m 44s	remaining: 1h 53m 15s
# 157:	learn: 0.9898775	test: 0.9825824	best: 0.9825824 (157)	total: 5m 47s	remaining: 1h 53m 13s
# 158:	learn: 0.9899127	test: 0.9827125	best: 0.9827125 (158)	total: 5m 49s	remaining: 1h 53m 11s
# 159:	learn: 0.9899405	test: 0.9827965	best: 0.9827965 (159)	total: 5m 51s	remaining: 1h 53m 7s
# 160:	learn: 0.9899701	test: 0.9828493	best: 0.9828493 (160)	total: 5m 53s	remaining: 1h 53m 10s
# 161:	learn: 0.9899892	test: 0.9828828	best: 0.9828828 (161)	total: 5m 55s	remaining: 1h 53m 3s
# 162:	learn: 0.9900124	test: 0.9829014	best: 0.9829014 (162)	total: 5m 57s	remaining: 1h 52m 59s
# 163:	learn: 0.9900349	test: 0.9829516	best: 0.9829516 (163)	total: 6m	remaining: 1h 52m 58s
# 164:	learn: 0.9900571	test: 0.9830096	best: 0.9830096 (164)	total: 6m 2s	remaining: 1h 52m 58s
# 165:	learn: 0.9900766	test: 0.9830360	best: 0.9830360 (165)	total: 6m 4s	remaining: 1h 52m 56s
# 166:	learn: 0.9900984	test: 0.9830967	best: 0.9830967 (166)	total: 6m 7s	remaining: 1h 52m 57s
# 167:	learn: 0.9901203	test: 0.9831215	best: 0.9831215 (167)	total: 6m 9s	remaining: 1h 52m 54s
# 168:	learn: 0.9901497	test: 0.9832281	best: 0.9832281 (168)	total: 6m 11s	remaining: 1h 52m 51s
# 169:	learn: 0.9901730	test: 0.9833060	best: 0.9833060 (169)	total: 6m 13s	remaining: 1h 52m 47s
# 170:	learn: 0.9901944	test: 0.9833689	best: 0.9833689 (170)	total: 6m 15s	remaining: 1h 52m 48s
# 171:	learn: 0.9902111	test: 0.9834099	best: 0.9834099 (171)	total: 6m 17s	remaining: 1h 52m 42s
# 172:	learn: 0.9902283	test: 0.9834267	best: 0.9834267 (172)	total: 6m 19s	remaining: 1h 52m 35s
# 173:	learn: 0.9902444	test: 0.9834528	best: 0.9834528 (173)	total: 6m 21s	remaining: 1h 52m 29s
# 174:	learn: 0.9902636	test: 0.9834699	best: 0.9834699 (174)	total: 6m 24s	remaining: 1h 52m 29s
# 175:	learn: 0.9902787	test: 0.9835042	best: 0.9835042 (175)	total: 6m 26s	remaining: 1h 52m 23s
# 176:	learn: 0.9902946	test: 0.9835306	best: 0.9835306 (176)	total: 6m 27s	remaining: 1h 52m 14s
# 177:	learn: 0.9903133	test: 0.9835523	best: 0.9835523 (177)	total: 6m 29s	remaining: 1h 52m 10s
# 178:	learn: 0.9903291	test: 0.9835652	best: 0.9835652 (178)	total: 6m 31s	remaining: 1h 52m 3s
# 179:	learn: 0.9903426	test: 0.9835889	best: 0.9835889 (179)	total: 6m 33s	remaining: 1h 51m 56s
# 180:	learn: 0.9903557	test: 0.9836068	best: 0.9836068 (180)	total: 6m 35s	remaining: 1h 51m 46s
# 181:	learn: 0.9903759	test: 0.9836629	best: 0.9836629 (181)	total: 6m 37s	remaining: 1h 51m 45s
# 182:	learn: 0.9903912	test: 0.9836936	best: 0.9836936 (182)	total: 6m 39s	remaining: 1h 51m 40s
# 183:	learn: 0.9904058	test: 0.9837056	best: 0.9837056 (183)	total: 6m 41s	remaining: 1h 51m 33s
# 184:	learn: 0.9904228	test: 0.9837266	best: 0.9837266 (184)	total: 6m 43s	remaining: 1h 51m 27s
# 185:	learn: 0.9904365	test: 0.9837541	best: 0.9837541 (185)	total: 6m 45s	remaining: 1h 51m 23s
# 186:	learn: 0.9904597	test: 0.9838466	best: 0.9838466 (186)	total: 6m 47s	remaining: 1h 51m 21s
# 187:	learn: 0.9904796	test: 0.9838814	best: 0.9838814 (187)	total: 6m 50s	remaining: 1h 51m 19s
# 188:	learn: 0.9904912	test: 0.9838989	best: 0.9838989 (188)	total: 6m 51s	remaining: 1h 51m 10s
# 189:	learn: 0.9905053	test: 0.9839118	best: 0.9839118 (189)	total: 6m 53s	remaining: 1h 51m 6s
# 190:	learn: 0.9905200	test: 0.9839256	best: 0.9839256 (190)	total: 6m 55s	remaining: 1h 51m
# 191:	learn: 0.9905323	test: 0.9839330	best: 0.9839330 (191)	total: 6m 57s	remaining: 1h 50m 53s
# 192:	learn: 0.9905471	test: 0.9839537	best: 0.9839537 (192)	total: 6m 59s	remaining: 1h 50m 47s
# 193:	learn: 0.9905598	test: 0.9839553	best: 0.9839553 (193)	total: 7m 1s	remaining: 1h 50m 40s
# 194:	learn: 0.9905729	test: 0.9839886	best: 0.9839886 (194)	total: 7m 3s	remaining: 1h 50m 33s
# 195:	learn: 0.9905858	test: 0.9840036	best: 0.9840036 (195)	total: 7m 5s	remaining: 1h 50m 27s
# 196:	learn: 0.9906069	test: 0.9840881	best: 0.9840881 (196)	total: 7m 7s	remaining: 1h 50m 26s
# 197:	learn: 0.9906214	test: 0.9841099	best: 0.9841099 (197)	total: 7m 9s	remaining: 1h 50m 22s
# 198:	learn: 0.9906357	test: 0.9841243	best: 0.9841243 (198)	total: 7m 11s	remaining: 1h 50m 21s
# 199:	learn: 0.9906507	test: 0.9841255	best: 0.9841255 (199)	total: 7m 13s	remaining: 1h 50m 16s
# 200:	learn: 0.9906672	test: 0.9841545	best: 0.9841545 (200)	total: 7m 16s	remaining: 1h 50m 13s
# 201:	learn: 0.9906845	test: 0.9842924	best: 0.9842924 (201)	total: 7m 18s	remaining: 1h 50m 11s
# 202:	learn: 0.9906940	test: 0.9842958	best: 0.9842958 (202)	total: 7m 19s	remaining: 1h 50m 3s
# 203:	learn: 0.9907055	test: 0.9843158	best: 0.9843158 (203)	total: 7m 21s	remaining: 1h 49m 58s
# 204:	learn: 0.9907215	test: 0.9843440	best: 0.9843440 (204)	total: 7m 24s	remaining: 1h 49m 57s
# 205:	learn: 0.9907335	test: 0.9843641	best: 0.9843641 (205)	total: 7m 26s	remaining: 1h 49m 51s
# 206:	learn: 0.9907471	test: 0.9843957	best: 0.9843957 (206)	total: 7m 28s	remaining: 1h 49m 48s
# 207:	learn: 0.9907632	test: 0.9843931	best: 0.9843957 (206)	total: 7m 30s	remaining: 1h 49m 46s
# 208:	learn: 0.9907764	test: 0.9844075	best: 0.9844075 (208)	total: 7m 32s	remaining: 1h 49m 43s
# 209:	learn: 0.9907851	test: 0.9844227	best: 0.9844227 (209)	total: 7m 34s	remaining: 1h 49m 37s
# 210:	learn: 0.9907977	test: 0.9844524	best: 0.9844524 (210)	total: 7m 36s	remaining: 1h 49m 34s
# 211:	learn: 0.9908112	test: 0.9844744	best: 0.9844744 (211)	total: 7m 38s	remaining: 1h 49m 32s
# 212:	learn: 0.9908240	test: 0.9844746	best: 0.9844746 (212)	total: 7m 40s	remaining: 1h 49m 28s
# 213:	learn: 0.9908404	test: 0.9844929	best: 0.9844929 (213)	total: 7m 42s	remaining: 1h 49m 26s
# 214:	learn: 0.9908577	test: 0.9845313	best: 0.9845313 (214)	total: 7m 45s	remaining: 1h 49m 28s
# 215:	learn: 0.9908732	test: 0.9845492	best: 0.9845492 (215)	total: 7m 47s	remaining: 1h 49m 27s
# 216:	learn: 0.9908823	test: 0.9845688	best: 0.9845688 (216)	total: 7m 49s	remaining: 1h 49m 21s
# 217:	learn: 0.9908921	test: 0.9845833	best: 0.9845833 (217)	total: 7m 51s	remaining: 1h 49m 17s
# 218:	learn: 0.9909029	test: 0.9846090	best: 0.9846090 (218)	total: 7m 53s	remaining: 1h 49m 14s
# 219:	learn: 0.9909166	test: 0.9846340	best: 0.9846340 (219)	total: 7m 55s	remaining: 1h 49m 11s
# 220:	learn: 0.9909255	test: 0.9846550	best: 0.9846550 (220)	total: 7m 57s	remaining: 1h 49m 9s
# 221:	learn: 0.9909363	test: 0.9846701	best: 0.9846701 (221)	total: 7m 59s	remaining: 1h 49m 5s
# 222:	learn: 0.9909489	test: 0.9846746	best: 0.9846746 (222)	total: 8m 2s	remaining: 1h 49m 6s
# 223:	learn: 0.9909577	test: 0.9846829	best: 0.9846829 (223)	total: 8m 4s	remaining: 1h 48m 59s
# 224:	learn: 0.9909654	test: 0.9846947	best: 0.9846947 (224)	total: 8m 5s	remaining: 1h 48m 53s
# 225:	learn: 0.9909753	test: 0.9847198	best: 0.9847198 (225)	total: 8m 7s	remaining: 1h 48m 46s
# 226:	learn: 0.9909886	test: 0.9847561	best: 0.9847561 (226)	total: 8m 10s	remaining: 1h 48m 48s
# 227:	learn: 0.9910021	test: 0.9847811	best: 0.9847811 (227)	total: 8m 12s	remaining: 1h 48m 43s
# 228:	learn: 0.9910129	test: 0.9847955	best: 0.9847955 (228)	total: 8m 14s	remaining: 1h 48m 41s
# 229:	learn: 0.9910235	test: 0.9848057	best: 0.9848057 (229)	total: 8m 16s	remaining: 1h 48m 36s
# 230:	learn: 0.9910345	test: 0.9848160	best: 0.9848160 (230)	total: 8m 18s	remaining: 1h 48m 32s
# 231:	learn: 0.9910430	test: 0.9848225	best: 0.9848225 (231)	total: 8m 20s	remaining: 1h 48m 26s
# 232:	learn: 0.9910491	test: 0.9848336	best: 0.9848336 (232)	total: 8m 21s	remaining: 1h 48m 20s
# 233:	learn: 0.9910568	test: 0.9848392	best: 0.9848392 (233)	total: 8m 23s	remaining: 1h 48m 12s
# 234:	learn: 0.9910686	test: 0.9848677	best: 0.9848677 (234)	total: 8m 25s	remaining: 1h 48m 8s
# 235:	learn: 0.9910787	test: 0.9848778	best: 0.9848778 (235)	total: 8m 27s	remaining: 1h 48m 5s
# 236:	learn: 0.9910908	test: 0.9848934	best: 0.9848934 (236)	total: 8m 29s	remaining: 1h 48m 2s
# 237:	learn: 0.9910978	test: 0.9848985	best: 0.9848985 (237)	total: 8m 31s	remaining: 1h 47m 57s
# 238:	learn: 0.9911072	test: 0.9849123	best: 0.9849123 (238)	total: 8m 34s	remaining: 1h 47m 56s
# 239:	learn: 0.9911173	test: 0.9849422	best: 0.9849422 (239)	total: 8m 35s	remaining: 1h 47m 50s
# 240:	learn: 0.9911277	test: 0.9849494	best: 0.9849494 (240)	total: 8m 38s	remaining: 1h 47m 48s
# 241:	learn: 0.9911368	test: 0.9849554	best: 0.9849554 (241)	total: 8m 40s	remaining: 1h 47m 46s
# 242:	learn: 0.9911426	test: 0.9849663	best: 0.9849663 (242)	total: 8m 41s	remaining: 1h 47m 39s
# 243:	learn: 0.9911537	test: 0.9850341	best: 0.9850341 (243)	total: 8m 43s	remaining: 1h 47m 34s
# 244:	learn: 0.9911628	test: 0.9850642	best: 0.9850642 (244)	total: 8m 45s	remaining: 1h 47m 29s
# 245:	learn: 0.9911700	test: 0.9850701	best: 0.9850701 (245)	total: 8m 47s	remaining: 1h 47m 23s
# 246:	learn: 0.9911774	test: 0.9850722	best: 0.9850722 (246)	total: 8m 49s	remaining: 1h 47m 16s
# 247:	learn: 0.9911930	test: 0.9850813	best: 0.9850813 (247)	total: 8m 51s	remaining: 1h 47m 15s
# 248:	learn: 0.9912035	test: 0.9850885	best: 0.9850885 (248)	total: 8m 53s	remaining: 1h 47m 10s
# 249:	learn: 0.9912133	test: 0.9850901	best: 0.9850901 (249)	total: 8m 55s	remaining: 1h 47m 6s
# 250:	learn: 0.9912280	test: 0.9851351	best: 0.9851351 (250)	total: 8m 57s	remaining: 1h 47m 6s
# 251:	learn: 0.9912378	test: 0.9851483	best: 0.9851483 (251)	total: 8m 59s	remaining: 1h 47m 2s
# 252:	learn: 0.9912474	test: 0.9851641	best: 0.9851641 (252)	total: 9m 1s	remaining: 1h 46m 59s
# 253:	learn: 0.9912585	test: 0.9851998	best: 0.9851998 (253)	total: 9m 4s	remaining: 1h 46m 58s
# 254:	learn: 0.9912649	test: 0.9851998	best: 0.9851998 (254)	total: 9m 5s	remaining: 1h 46m 52s
# 255:	learn: 0.9912749	test: 0.9852020	best: 0.9852020 (255)	total: 9m 7s	remaining: 1h 46m 48s
# 256:	learn: 0.9912828	test: 0.9852140	best: 0.9852140 (256)	total: 9m 10s	remaining: 1h 46m 45s
# 257:	learn: 0.9912923	test: 0.9852442	best: 0.9852442 (257)	total: 9m 12s	remaining: 1h 46m 44s
# 258:	learn: 0.9913022	test: 0.9852586	best: 0.9852586 (258)	total: 9m 14s	remaining: 1h 46m 44s
# 259:	learn: 0.9913119	test: 0.9852758	best: 0.9852758 (259)	total: 9m 16s	remaining: 1h 46m 42s
# 260:	learn: 0.9913215	test: 0.9852891	best: 0.9852891 (260)	total: 9m 18s	remaining: 1h 46m 39s
# 261:	learn: 0.9913307	test: 0.9853286	best: 0.9853286 (261)	total: 9m 20s	remaining: 1h 46m 36s
# 262:	learn: 0.9913428	test: 0.9853412	best: 0.9853412 (262)	total: 9m 23s	remaining: 1h 46m 34s
# 263:	learn: 0.9913499	test: 0.9853540	best: 0.9853540 (263)	total: 9m 24s	remaining: 1h 46m 28s
# 264:	learn: 0.9913579	test: 0.9853661	best: 0.9853661 (264)	total: 9m 26s	remaining: 1h 46m 26s
# 265:	learn: 0.9913641	test: 0.9853736	best: 0.9853736 (265)	total: 9m 28s	remaining: 1h 46m 19s
# 266:	learn: 0.9913741	test: 0.9853836	best: 0.9853836 (266)	total: 9m 30s	remaining: 1h 46m 19s
# 267:	learn: 0.9913893	test: 0.9854560	best: 0.9854560 (267)	total: 9m 32s	remaining: 1h 46m 14s
# 268:	learn: 0.9913979	test: 0.9854850	best: 0.9854850 (268)	total: 9m 35s	remaining: 1h 46m 12s
# 269:	learn: 0.9914064	test: 0.9854943	best: 0.9854943 (269)	total: 9m 37s	remaining: 1h 46m 10s
# 270:	learn: 0.9914181	test: 0.9854989	best: 0.9854989 (270)	total: 9m 39s	remaining: 1h 46m 8s
# 271:	learn: 0.9914281	test: 0.9855115	best: 0.9855115 (271)	total: 9m 41s	remaining: 1h 46m 8s
# 272:	learn: 0.9914400	test: 0.9855295	best: 0.9855295 (272)	total: 9m 44s	remaining: 1h 46m 8s
# 273:	learn: 0.9914474	test: 0.9855297	best: 0.9855297 (273)	total: 9m 45s	remaining: 1h 46m 2s
# 274:	learn: 0.9914551	test: 0.9855564	best: 0.9855564 (274)	total: 9m 47s	remaining: 1h 46m
# 275:	learn: 0.9914717	test: 0.9856880	best: 0.9856880 (275)	total: 9m 50s	remaining: 1h 46m 1s
# 276:	learn: 0.9914778	test: 0.9857194	best: 0.9857194 (276)	total: 9m 52s	remaining: 1h 45m 57s
# 277:	learn: 0.9914835	test: 0.9857314	best: 0.9857314 (277)	total: 9m 54s	remaining: 1h 45m 50s
# 278:	learn: 0.9914929	test: 0.9857414	best: 0.9857414 (278)	total: 9m 56s	remaining: 1h 45m 50s
# 279:	learn: 0.9915017	test: 0.9857542	best: 0.9857542 (279)	total: 9m 58s	remaining: 1h 45m 51s
# 280:	learn: 0.9915074	test: 0.9857654	best: 0.9857654 (280)	total: 10m	remaining: 1h 45m 44s
# 281:	learn: 0.9915134	test: 0.9857716	best: 0.9857716 (281)	total: 10m 2s	remaining: 1h 45m 40s
# 282:	learn: 0.9915199	test: 0.9857871	best: 0.9857871 (282)	total: 10m 4s	remaining: 1h 45m 37s
# 283:	learn: 0.9915284	test: 0.9857825	best: 0.9857871 (282)	total: 10m 6s	remaining: 1h 45m 33s
# 284:	learn: 0.9915436	test: 0.9858691	best: 0.9858691 (284)	total: 10m 8s	remaining: 1h 45m 34s
# 285:	learn: 0.9915489	test: 0.9858729	best: 0.9858729 (285)	total: 10m 10s	remaining: 1h 45m 28s
# 286:	learn: 0.9915565	test: 0.9858719	best: 0.9858729 (285)	total: 10m 12s	remaining: 1h 45m 24s
# 287:	learn: 0.9915646	test: 0.9858802	best: 0.9858802 (287)	total: 10m 14s	remaining: 1h 45m 21s
# 288:	learn: 0.9915769	test: 0.9859471	best: 0.9859471 (288)	total: 10m 16s	remaining: 1h 45m 20s
# 289:	learn: 0.9915819	test: 0.9859448	best: 0.9859471 (288)	total: 10m 18s	remaining: 1h 45m 16s
# 290:	learn: 0.9915880	test: 0.9859498	best: 0.9859498 (290)	total: 10m 20s	remaining: 1h 45m 12s
# 291:	learn: 0.9915984	test: 0.9859689	best: 0.9859689 (291)	total: 10m 23s	remaining: 1h 45m 11s
# 292:	learn: 0.9916050	test: 0.9859760	best: 0.9859760 (292)	total: 10m 24s	remaining: 1h 45m 6s
# 293:	learn: 0.9916117	test: 0.9859976	best: 0.9859976 (293)	total: 10m 26s	remaining: 1h 45m 3s
# 294:	learn: 0.9916259	test: 0.9860695	best: 0.9860695 (294)	total: 10m 28s	remaining: 1h 45m
# 295:	learn: 0.9916342	test: 0.9860711	best: 0.9860711 (295)	total: 10m 31s	remaining: 1h 44m 57s
# 296:	learn: 0.9916411	test: 0.9861135	best: 0.9861135 (296)	total: 10m 33s	remaining: 1h 44m 53s
# 297:	learn: 0.9916470	test: 0.9861273	best: 0.9861273 (297)	total: 10m 35s	remaining: 1h 44m 52s
# 298:	learn: 0.9916603	test: 0.9861820	best: 0.9861820 (298)	total: 10m 37s	remaining: 1h 44m 52s
# 299:	learn: 0.9916683	test: 0.9861981	best: 0.9861981 (299)	total: 10m 39s	remaining: 1h 44m 52s
# 300:	learn: 0.9916769	test: 0.9861955	best: 0.9861981 (299)	total: 10m 41s	remaining: 1h 44m 49s
# 301:	learn: 0.9916827	test: 0.9862080	best: 0.9862080 (301)	total: 10m 43s	remaining: 1h 44m 45s
# 302:	learn: 0.9916897	test: 0.9862165	best: 0.9862165 (302)	total: 10m 45s	remaining: 1h 44m 41s
# 303:	learn: 0.9916999	test: 0.9862261	best: 0.9862261 (303)	total: 10m 48s	remaining: 1h 44m 40s
# 304:	learn: 0.9917086	test: 0.9862365	best: 0.9862365 (304)	total: 10m 50s	remaining: 1h 44m 40s
# 305:	learn: 0.9917178	test: 0.9862648	best: 0.9862648 (305)	total: 10m 52s	remaining: 1h 44m 38s
# 306:	learn: 0.9917259	test: 0.9862632	best: 0.9862648 (305)	total: 10m 54s	remaining: 1h 44m 35s
# 307:	learn: 0.9917329	test: 0.9862758	best: 0.9862758 (307)	total: 10m 56s	remaining: 1h 44m 32s
# 308:	learn: 0.9917455	test: 0.9862878	best: 0.9862878 (308)	total: 10m 58s	remaining: 1h 44m 28s
# 309:	learn: 0.9917514	test: 0.9862939	best: 0.9862939 (309)	total: 11m	remaining: 1h 44m 23s
# 310:	learn: 0.9917609	test: 0.9863115	best: 0.9863115 (310)	total: 11m 2s	remaining: 1h 44m 21s
# 311:	learn: 0.9917674	test: 0.9863171	best: 0.9863171 (311)	total: 11m 4s	remaining: 1h 44m 18s
# 312:	learn: 0.9917747	test: 0.9863516	best: 0.9863516 (312)	total: 11m 6s	remaining: 1h 44m 12s
# 313:	learn: 0.9917824	test: 0.9863544	best: 0.9863544 (313)	total: 11m 8s	remaining: 1h 44m 11s
# 314:	learn: 0.9917878	test: 0.9863617	best: 0.9863617 (314)	total: 11m 10s	remaining: 1h 44m 8s
# 315:	learn: 0.9917962	test: 0.9863734	best: 0.9863734 (315)	total: 11m 12s	remaining: 1h 44m 8s
# 316:	learn: 0.9918019	test: 0.9863933	best: 0.9863933 (316)	total: 11m 15s	remaining: 1h 44m 5s
# 317:	learn: 0.9918085	test: 0.9864051	best: 0.9864051 (317)	total: 11m 17s	remaining: 1h 44m 2s
# 318:	learn: 0.9918158	test: 0.9864274	best: 0.9864274 (318)	total: 11m 19s	remaining: 1h 43m 58s
# 319:	learn: 0.9918235	test: 0.9864457	best: 0.9864457 (319)	total: 11m 21s	remaining: 1h 43m 56s
# 320:	learn: 0.9918318	test: 0.9864573	best: 0.9864573 (320)	total: 11m 23s	remaining: 1h 43m 54s
# 321:	learn: 0.9918385	test: 0.9864550	best: 0.9864573 (320)	total: 11m 25s	remaining: 1h 43m 51s
# 322:	learn: 0.9918453	test: 0.9864695	best: 0.9864695 (322)	total: 11m 27s	remaining: 1h 43m 47s
# 323:	learn: 0.9918505	test: 0.9864752	best: 0.9864752 (323)	total: 11m 29s	remaining: 1h 43m 46s
# 324:	learn: 0.9918570	test: 0.9864857	best: 0.9864857 (324)	total: 11m 31s	remaining: 1h 43m 43s
# 325:	learn: 0.9918675	test: 0.9865727	best: 0.9865727 (325)	total: 11m 33s	remaining: 1h 43m 40s
# 326:	learn: 0.9918788	test: 0.9866270	best: 0.9866270 (326)	total: 11m 35s	remaining: 1h 43m 37s
# 327:	learn: 0.9918856	test: 0.9866467	best: 0.9866467 (327)	total: 11m 37s	remaining: 1h 43m 34s
# 328:	learn: 0.9918909	test: 0.9866491	best: 0.9866491 (328)	total: 11m 39s	remaining: 1h 43m 31s
# 329:	learn: 0.9918971	test: 0.9866496	best: 0.9866496 (329)	total: 11m 41s	remaining: 1h 43m 25s
# 330:	learn: 0.9919035	test: 0.9866593	best: 0.9866593 (330)	total: 11m 43s	remaining: 1h 43m 22s
# 331:	learn: 0.9919104	test: 0.9866752	best: 0.9866752 (331)	total: 11m 45s	remaining: 1h 43m 21s
# 332:	learn: 0.9919175	test: 0.9866849	best: 0.9866849 (332)	total: 11m 47s	remaining: 1h 43m 19s
# 333:	learn: 0.9919275	test: 0.9866929	best: 0.9866929 (333)	total: 11m 49s	remaining: 1h 43m 16s
# 334:	learn: 0.9919324	test: 0.9866949	best: 0.9866949 (334)	total: 11m 51s	remaining: 1h 43m 12s
# 335:	learn: 0.9919385	test: 0.9867192	best: 0.9867192 (335)	total: 11m 53s	remaining: 1h 43m 8s
# 336:	learn: 0.9919464	test: 0.9867332	best: 0.9867332 (336)	total: 11m 55s	remaining: 1h 43m 5s
# 337:	learn: 0.9919560	test: 0.9867381	best: 0.9867381 (337)	total: 11m 57s	remaining: 1h 43m 3s
# 338:	learn: 0.9919653	test: 0.9867379	best: 0.9867381 (337)	total: 11m 59s	remaining: 1h 43m
# 339:	learn: 0.9919705	test: 0.9867379	best: 0.9867381 (337)	total: 12m 1s	remaining: 1h 42m 56s
# 340:	learn: 0.9919758	test: 0.9867395	best: 0.9867395 (340)	total: 12m 3s	remaining: 1h 42m 51s
# 341:	learn: 0.9919815	test: 0.9867442	best: 0.9867442 (341)	total: 12m 5s	remaining: 1h 42m 47s
# 342:	learn: 0.9919934	test: 0.9868552	best: 0.9868552 (342)	total: 12m 7s	remaining: 1h 42m 44s
# 343:	learn: 0.9919990	test: 0.9868688	best: 0.9868688 (343)	total: 12m 9s	remaining: 1h 42m 41s
# 344:	learn: 0.9920060	test: 0.9869001	best: 0.9869001 (344)	total: 12m 11s	remaining: 1h 42m 39s
# 345:	learn: 0.9920125	test: 0.9869038	best: 0.9869038 (345)	total: 12m 13s	remaining: 1h 42m 35s
# 346:	learn: 0.9920185	test: 0.9869244	best: 0.9869244 (346)	total: 12m 15s	remaining: 1h 42m 33s
# 347:	learn: 0.9920281	test: 0.9869685	best: 0.9869685 (347)	total: 12m 17s	remaining: 1h 42m 31s
# 348:	learn: 0.9920364	test: 0.9869733	best: 0.9869733 (348)	total: 12m 19s	remaining: 1h 42m 27s
# 349:	learn: 0.9920417	test: 0.9869805	best: 0.9869805 (349)	total: 12m 21s	remaining: 1h 42m 23s
# 350:	learn: 0.9920460	test: 0.9869864	best: 0.9869864 (350)	total: 12m 23s	remaining: 1h 42m 21s
# 351:	learn: 0.9920502	test: 0.9869903	best: 0.9869903 (351)	total: 12m 25s	remaining: 1h 42m 17s
# 352:	learn: 0.9920540	test: 0.9869912	best: 0.9869912 (352)	total: 12m 27s	remaining: 1h 42m 12s
# 353:	learn: 0.9920600	test: 0.9870006	best: 0.9870006 (353)	total: 12m 29s	remaining: 1h 42m 11s
# 354:	learn: 0.9920684	test: 0.9870316	best: 0.9870316 (354)	total: 12m 31s	remaining: 1h 42m 11s
# 355:	learn: 0.9920727	test: 0.9870340	best: 0.9870340 (355)	total: 12m 33s	remaining: 1h 42m 8s
# 356:	learn: 0.9920771	test: 0.9870439	best: 0.9870439 (356)	total: 12m 35s	remaining: 1h 42m 5s
# 357:	learn: 0.9920859	test: 0.9870919	best: 0.9870919 (357)	total: 12m 38s	remaining: 1h 42m 4s
# 358:	learn: 0.9920902	test: 0.9871042	best: 0.9871042 (358)	total: 12m 39s	remaining: 1h 41m 58s
# 359:	learn: 0.9920989	test: 0.9871105	best: 0.9871105 (359)	total: 12m 42s	remaining: 1h 41m 57s
# 360:	learn: 0.9921032	test: 0.9871177	best: 0.9871177 (360)	total: 12m 44s	remaining: 1h 41m 54s
# 361:	learn: 0.9921078	test: 0.9871600	best: 0.9871600 (361)	total: 12m 46s	remaining: 1h 41m 52s
# 362:	learn: 0.9921124	test: 0.9871638	best: 0.9871638 (362)	total: 12m 48s	remaining: 1h 41m 50s
# 363:	learn: 0.9921242	test: 0.9871846	best: 0.9871846 (363)	total: 12m 50s	remaining: 1h 41m 48s
# 364:	learn: 0.9921300	test: 0.9872583	best: 0.9872583 (364)	total: 12m 52s	remaining: 1h 41m 45s
# 365:	learn: 0.9921378	test: 0.9873030	best: 0.9873030 (365)	total: 12m 54s	remaining: 1h 41m 43s
# 366:	learn: 0.9921454	test: 0.9873254	best: 0.9873254 (366)	total: 12m 56s	remaining: 1h 41m 41s
# 367:	learn: 0.9921512	test: 0.9873403	best: 0.9873403 (367)	total: 12m 58s	remaining: 1h 41m 39s
# 368:	learn: 0.9921576	test: 0.9873479	best: 0.9873479 (368)	total: 13m	remaining: 1h 41m 37s
# 369:	learn: 0.9921622	test: 0.9873493	best: 0.9873493 (369)	total: 13m 2s	remaining: 1h 41m 31s
# 370:	learn: 0.9921669	test: 0.9873523	best: 0.9873523 (370)	total: 13m 4s	remaining: 1h 41m 29s
# 371:	learn: 0.9921722	test: 0.9873601	best: 0.9873601 (371)	total: 13m 6s	remaining: 1h 41m 27s
# 372:	learn: 0.9921771	test: 0.9873707	best: 0.9873707 (372)	total: 13m 8s	remaining: 1h 41m 23s
# 373:	learn: 0.9921848	test: 0.9873800	best: 0.9873800 (373)	total: 13m 10s	remaining: 1h 41m 20s
# 374:	learn: 0.9921931	test: 0.9874182	best: 0.9874182 (374)	total: 13m 12s	remaining: 1h 41m 18s
# 375:	learn: 0.9922056	test: 0.9874601	best: 0.9874601 (375)	total: 13m 15s	remaining: 1h 41m 19s
# 376:	learn: 0.9922154	test: 0.9875559	best: 0.9875559 (376)	total: 13m 17s	remaining: 1h 41m 16s
# 377:	learn: 0.9922204	test: 0.9875675	best: 0.9875675 (377)	total: 13m 19s	remaining: 1h 41m 14s
# 378:	learn: 0.9922249	test: 0.9875876	best: 0.9875876 (378)	total: 13m 21s	remaining: 1h 41m 11s
# 379:	learn: 0.9922325	test: 0.9875930	best: 0.9875930 (379)	total: 13m 23s	remaining: 1h 41m 10s
# 380:	learn: 0.9922432	test: 0.9876748	best: 0.9876748 (380)	total: 13m 25s	remaining: 1h 41m 8s
# 381:	learn: 0.9922459	test: 0.9876773	best: 0.9876773 (381)	total: 13m 27s	remaining: 1h 41m 4s
# 382:	learn: 0.9922525	test: 0.9876855	best: 0.9876855 (382)	total: 13m 29s	remaining: 1h 40m 59s
# 383:	learn: 0.9922583	test: 0.9876866	best: 0.9876866 (383)	total: 13m 31s	remaining: 1h 40m 55s
# 384:	learn: 0.9922650	test: 0.9877027	best: 0.9877027 (384)	total: 13m 33s	remaining: 1h 40m 55s
# 385:	learn: 0.9922705	test: 0.9877078	best: 0.9877078 (385)	total: 13m 35s	remaining: 1h 40m 53s
# 386:	learn: 0.9922777	test: 0.9877163	best: 0.9877163 (386)	total: 13m 38s	remaining: 1h 40m 54s
# 387:	learn: 0.9922838	test: 0.9877380	best: 0.9877380 (387)	total: 13m 40s	remaining: 1h 40m 49s
# 388:	learn: 0.9922891	test: 0.9877763	best: 0.9877763 (388)	total: 13m 42s	remaining: 1h 40m 47s
# 389:	learn: 0.9922948	test: 0.9877918	best: 0.9877918 (389)	total: 13m 44s	remaining: 1h 40m 44s
# 390:	learn: 0.9923008	test: 0.9878339	best: 0.9878339 (390)	total: 13m 46s	remaining: 1h 40m 41s
# 391:	learn: 0.9923060	test: 0.9878374	best: 0.9878374 (391)	total: 13m 48s	remaining: 1h 40m 37s
# 392:	learn: 0.9923113	test: 0.9878445	best: 0.9878445 (392)	total: 13m 50s	remaining: 1h 40m 34s
# 393:	learn: 0.9923181	test: 0.9878593	best: 0.9878593 (393)	total: 13m 52s	remaining: 1h 40m 33s
# 394:	learn: 0.9923242	test: 0.9878627	best: 0.9878627 (394)	total: 13m 54s	remaining: 1h 40m 30s
# 395:	learn: 0.9923289	test: 0.9878704	best: 0.9878704 (395)	total: 13m 56s	remaining: 1h 40m 27s
# 396:	learn: 0.9923330	test: 0.9878726	best: 0.9878726 (396)	total: 13m 58s	remaining: 1h 40m 25s
# 397:	learn: 0.9923383	test: 0.9878791	best: 0.9878791 (397)	total: 14m	remaining: 1h 40m 21s
# 398:	learn: 0.9923486	test: 0.9878953	best: 0.9878953 (398)	total: 14m 2s	remaining: 1h 40m 20s
# 399:	learn: 0.9923557	test: 0.9879179	best: 0.9879179 (399)	total: 14m 4s	remaining: 1h 40m 19s
# 400:	learn: 0.9923602	test: 0.9879282	best: 0.9879282 (400)	total: 14m 6s	remaining: 1h 40m 16s
# 401:	learn: 0.9923650	test: 0.9879290	best: 0.9879290 (401)	total: 14m 8s	remaining: 1h 40m 12s
# 402:	learn: 0.9923724	test: 0.9879432	best: 0.9879432 (402)	total: 14m 11s	remaining: 1h 40m 11s
# 403:	learn: 0.9923792	test: 0.9879548	best: 0.9879548 (403)	total: 14m 13s	remaining: 1h 40m 9s
# 404:	learn: 0.9923842	test: 0.9879600	best: 0.9879600 (404)	total: 14m 15s	remaining: 1h 40m 7s
# 405:	learn: 0.9923912	test: 0.9879677	best: 0.9879677 (405)	total: 14m 17s	remaining: 1h 40m 6s
# 406:	learn: 0.9923969	test: 0.9879757	best: 0.9879757 (406)	total: 14m 19s	remaining: 1h 40m 7s
# 407:	learn: 0.9924038	test: 0.9880188	best: 0.9880188 (407)	total: 14m 21s	remaining: 1h 40m 4s
# 408:	learn: 0.9924067	test: 0.9880209	best: 0.9880209 (408)	total: 14m 23s	remaining: 1h 40m
# 409:	learn: 0.9924135	test: 0.9880312	best: 0.9880312 (409)	total: 14m 26s	remaining: 1h 40m 1s
# 410:	learn: 0.9924201	test: 0.9880404	best: 0.9880404 (410)	total: 14m 28s	remaining: 1h 39m 59s
# 411:	learn: 0.9924268	test: 0.9880427	best: 0.9880427 (411)	total: 14m 30s	remaining: 1h 39m 56s
# 412:	learn: 0.9924333	test: 0.9880493	best: 0.9880493 (412)	total: 14m 32s	remaining: 1h 39m 55s
# 413:	learn: 0.9924410	test: 0.9880516	best: 0.9880516 (413)	total: 14m 35s	remaining: 1h 39m 56s
# 414:	learn: 0.9924487	test: 0.9881065	best: 0.9881065 (414)	total: 14m 37s	remaining: 1h 39m 57s
# 415:	learn: 0.9924538	test: 0.9881182	best: 0.9881182 (415)	total: 14m 39s	remaining: 1h 39m 53s
# 416:	learn: 0.9924600	test: 0.9881215	best: 0.9881215 (416)	total: 14m 41s	remaining: 1h 39m 49s
# 417:	learn: 0.9924642	test: 0.9881295	best: 0.9881295 (417)	total: 14m 43s	remaining: 1h 39m 47s
# 418:	learn: 0.9924705	test: 0.9881366	best: 0.9881366 (418)	total: 14m 46s	remaining: 1h 39m 47s
# 419:	learn: 0.9924756	test: 0.9881444	best: 0.9881444 (419)	total: 14m 48s	remaining: 1h 39m 47s
# 420:	learn: 0.9924813	test: 0.9881545	best: 0.9881545 (420)	total: 14m 50s	remaining: 1h 39m 46s
# 421:	learn: 0.9924860	test: 0.9881599	best: 0.9881599 (421)	total: 14m 52s	remaining: 1h 39m 42s
# 422:	learn: 0.9924907	test: 0.9881641	best: 0.9881641 (422)	total: 14m 54s	remaining: 1h 39m 39s
# 423:	learn: 0.9924973	test: 0.9881757	best: 0.9881757 (423)	total: 14m 57s	remaining: 1h 39m 38s
# 424:	learn: 0.9925013	test: 0.9881794	best: 0.9881794 (424)	total: 14m 59s	remaining: 1h 39m 36s
# 425:	learn: 0.9925073	test: 0.9881835	best: 0.9881835 (425)	total: 15m 1s	remaining: 1h 39m 35s
# 426:	learn: 0.9925119	test: 0.9881883	best: 0.9881883 (426)	total: 15m 3s	remaining: 1h 39m 33s
# 427:	learn: 0.9925174	test: 0.9882129	best: 0.9882129 (427)	total: 15m 5s	remaining: 1h 39m 30s
# 428:	learn: 0.9925234	test: 0.9882087	best: 0.9882129 (427)	total: 15m 7s	remaining: 1h 39m 29s
# 429:	learn: 0.9925275	test: 0.9882249	best: 0.9882249 (429)	total: 15m 9s	remaining: 1h 39m 26s
# 430:	learn: 0.9925305	test: 0.9882251	best: 0.9882251 (430)	total: 15m 11s	remaining: 1h 39m 22s
# 431:	learn: 0.9925363	test: 0.9882298	best: 0.9882298 (431)	total: 15m 13s	remaining: 1h 39m 20s
# 432:	learn: 0.9925396	test: 0.9882300	best: 0.9882300 (432)	total: 15m 15s	remaining: 1h 39m 15s
# 433:	learn: 0.9925435	test: 0.9882283	best: 0.9882300 (432)	total: 15m 17s	remaining: 1h 39m 12s
# 434:	learn: 0.9925480	test: 0.9882316	best: 0.9882316 (434)	total: 15m 19s	remaining: 1h 39m 9s
# 435:	learn: 0.9925524	test: 0.9882390	best: 0.9882390 (435)	total: 15m 21s	remaining: 1h 39m 7s
# 436:	learn: 0.9925557	test: 0.9882499	best: 0.9882499 (436)	total: 15m 23s	remaining: 1h 39m 6s
# 437:	learn: 0.9925626	test: 0.9882474	best: 0.9882499 (436)	total: 15m 25s	remaining: 1h 39m 3s
# 438:	learn: 0.9925687	test: 0.9882521	best: 0.9882521 (438)	total: 15m 27s	remaining: 1h 39m
# 439:	learn: 0.9925732	test: 0.9882578	best: 0.9882578 (439)	total: 15m 29s	remaining: 1h 38m 56s
# 440:	learn: 0.9925773	test: 0.9882642	best: 0.9882642 (440)	total: 15m 31s	remaining: 1h 38m 54s
# 441:	learn: 0.9925815	test: 0.9882706	best: 0.9882706 (441)	total: 15m 33s	remaining: 1h 38m 52s
# 442:	learn: 0.9925871	test: 0.9882749	best: 0.9882749 (442)	total: 15m 35s	remaining: 1h 38m 50s
# 443:	learn: 0.9925918	test: 0.9883074	best: 0.9883074 (443)	total: 15m 37s	remaining: 1h 38m 46s
# 444:	learn: 0.9925993	test: 0.9883483	best: 0.9883483 (444)	total: 15m 39s	remaining: 1h 38m 43s
# 445:	learn: 0.9926026	test: 0.9883482	best: 0.9883483 (444)	total: 15m 41s	remaining: 1h 38m 40s
# 446:	learn: 0.9926074	test: 0.9883589	best: 0.9883589 (446)	total: 15m 43s	remaining: 1h 38m 39s
# 447:	learn: 0.9926129	test: 0.9883990	best: 0.9883990 (447)	total: 15m 46s	remaining: 1h 38m 36s
# 448:	learn: 0.9926218	test: 0.9884733	best: 0.9884733 (448)	total: 15m 48s	remaining: 1h 38m 34s
# 449:	learn: 0.9926275	test: 0.9884824	best: 0.9884824 (449)	total: 15m 50s	remaining: 1h 38m 34s
# 450:	learn: 0.9926317	test: 0.9884872	best: 0.9884872 (450)	total: 15m 52s	remaining: 1h 38m 32s
# 451:	learn: 0.9926355	test: 0.9885100	best: 0.9885100 (451)	total: 15m 54s	remaining: 1h 38m 30s
# 452:	learn: 0.9926399	test: 0.9885187	best: 0.9885187 (452)	total: 15m 56s	remaining: 1h 38m 28s
# 453:	learn: 0.9926423	test: 0.9885188	best: 0.9885188 (453)	total: 15m 58s	remaining: 1h 38m 23s
# 454:	learn: 0.9926469	test: 0.9885282	best: 0.9885282 (454)	total: 16m	remaining: 1h 38m 21s
# 455:	learn: 0.9926532	test: 0.9885332	best: 0.9885332 (455)	total: 16m 2s	remaining: 1h 38m 19s
# 456:	learn: 0.9926573	test: 0.9885417	best: 0.9885417 (456)	total: 16m 4s	remaining: 1h 38m 17s
# 457:	learn: 0.9926609	test: 0.9885511	best: 0.9885511 (457)	total: 16m 7s	remaining: 1h 38m 15s
# 458:	learn: 0.9926649	test: 0.9885599	best: 0.9885599 (458)	total: 16m 9s	remaining: 1h 38m 12s
# 459:	learn: 0.9926682	test: 0.9885970	best: 0.9885970 (459)	total: 16m 11s	remaining: 1h 38m 10s
# 460:	learn: 0.9926729	test: 0.9886220	best: 0.9886220 (460)	total: 16m 13s	remaining: 1h 38m 7s
# 461:	learn: 0.9926787	test: 0.9886423	best: 0.9886423 (461)	total: 16m 15s	remaining: 1h 38m 6s
# 462:	learn: 0.9926826	test: 0.9886411	best: 0.9886423 (461)	total: 16m 17s	remaining: 1h 38m 2s
# 463:	learn: 0.9926901	test: 0.9887215	best: 0.9887215 (463)	total: 16m 19s	remaining: 1h 37m 59s
# 464:	learn: 0.9926938	test: 0.9887316	best: 0.9887316 (464)	total: 16m 21s	remaining: 1h 37m 58s
# 465:	learn: 0.9927007	test: 0.9887560	best: 0.9887560 (465)	total: 16m 23s	remaining: 1h 37m 57s
# 466:	learn: 0.9927045	test: 0.9887618	best: 0.9887618 (466)	total: 16m 25s	remaining: 1h 37m 55s
# 467:	learn: 0.9927079	test: 0.9887628	best: 0.9887628 (467)	total: 16m 28s	remaining: 1h 37m 53s
# 468:	learn: 0.9927153	test: 0.9887954	best: 0.9887954 (468)	total: 16m 30s	remaining: 1h 37m 52s
# 469:	learn: 0.9927201	test: 0.9887976	best: 0.9887976 (469)	total: 16m 32s	remaining: 1h 37m 51s
# 470:	learn: 0.9927257	test: 0.9888061	best: 0.9888061 (470)	total: 16m 34s	remaining: 1h 37m 50s
# 471:	learn: 0.9927337	test: 0.9888672	best: 0.9888672 (471)	total: 16m 37s	remaining: 1h 37m 49s
# 472:	learn: 0.9927368	test: 0.9888672	best: 0.9888672 (472)	total: 16m 39s	remaining: 1h 37m 45s
# 473:	learn: 0.9927416	test: 0.9888755	best: 0.9888755 (473)	total: 16m 41s	remaining: 1h 37m 42s
# 474:	learn: 0.9927465	test: 0.9888792	best: 0.9888792 (474)	total: 16m 43s	remaining: 1h 37m 42s
# 475:	learn: 0.9927505	test: 0.9888890	best: 0.9888890 (475)	total: 16m 45s	remaining: 1h 37m 39s
# 476:	learn: 0.9927541	test: 0.9888913	best: 0.9888913 (476)	total: 16m 47s	remaining: 1h 37m 36s
# 477:	learn: 0.9927612	test: 0.9889125	best: 0.9889125 (477)	total: 16m 49s	remaining: 1h 37m 34s
# 478:	learn: 0.9927659	test: 0.9889125	best: 0.9889125 (478)	total: 16m 51s	remaining: 1h 37m 32s
# 479:	learn: 0.9927708	test: 0.9889204	best: 0.9889204 (479)	total: 16m 53s	remaining: 1h 37m 31s
# 480:	learn: 0.9927741	test: 0.9889285	best: 0.9889285 (480)	total: 16m 55s	remaining: 1h 37m 27s
# 481:	learn: 0.9927792	test: 0.9889468	best: 0.9889468 (481)	total: 16m 58s	remaining: 1h 37m 26s
# 482:	learn: 0.9927835	test: 0.9889648	best: 0.9889648 (482)	total: 17m	remaining: 1h 37m 24s
# 483:	learn: 0.9927871	test: 0.9889664	best: 0.9889664 (483)	total: 17m 2s	remaining: 1h 37m 21s
# 484:	learn: 0.9927912	test: 0.9889811	best: 0.9889811 (484)	total: 17m 4s	remaining: 1h 37m 18s
# 485:	learn: 0.9927946	test: 0.9889871	best: 0.9889871 (485)	total: 17m 6s	remaining: 1h 37m 15s
# 486:	learn: 0.9928003	test: 0.9889963	best: 0.9889963 (486)	total: 17m 8s	remaining: 1h 37m 14s
# 487:	learn: 0.9928045	test: 0.9889972	best: 0.9889972 (487)	total: 17m 10s	remaining: 1h 37m 12s
# 488:	learn: 0.9928109	test: 0.9890213	best: 0.9890213 (488)	total: 17m 12s	remaining: 1h 37m 11s
# 489:	learn: 0.9928150	test: 0.9890481	best: 0.9890481 (489)	total: 17m 14s	remaining: 1h 37m 8s
# 490:	learn: 0.9928189	test: 0.9890553	best: 0.9890553 (490)	total: 17m 16s	remaining: 1h 37m 6s
# 491:	learn: 0.9928252	test: 0.9890544	best: 0.9890553 (490)	total: 17m 18s	remaining: 1h 37m 3s
# 492:	learn: 0.9928320	test: 0.9890719	best: 0.9890719 (492)	total: 17m 20s	remaining: 1h 37m 1s
# 493:	learn: 0.9928369	test: 0.9890898	best: 0.9890898 (493)	total: 17m 23s	remaining: 1h 36m 59s
# 494:	learn: 0.9928401	test: 0.9890973	best: 0.9890973 (494)	total: 17m 25s	remaining: 1h 36m 58s
# 495:	learn: 0.9928427	test: 0.9890972	best: 0.9890973 (494)	total: 17m 27s	remaining: 1h 36m 54s
# 496:	learn: 0.9928492	test: 0.9890982	best: 0.9890982 (496)	total: 17m 29s	remaining: 1h 36m 53s
# 497:	learn: 0.9928526	test: 0.9890971	best: 0.9890982 (496)	total: 17m 31s	remaining: 1h 36m 49s
# 498:	learn: 0.9928590	test: 0.9891209	best: 0.9891209 (498)	total: 17m 33s	remaining: 1h 36m 47s
# 499:	learn: 0.9928643	test: 0.9891237	best: 0.9891237 (499)	total: 17m 35s	remaining: 1h 36m 47s
# 500:	learn: 0.9928687	test: 0.9891298	best: 0.9891298 (500)	total: 17m 38s	remaining: 1h 36m 45s
# 501:	learn: 0.9928730	test: 0.9891302	best: 0.9891302 (501)	total: 17m 40s	remaining: 1h 36m 42s
# ...
# 3088:	learn: 0.9955922	test: 0.9949483	best: 0.9949486 (3087)	total: 1h 49m 32s	remaining: 5m 42s
# 3089:	learn: 0.9955926	test: 0.9949486	best: 0.9949486 (3087)	total: 1h 49m 34s	remaining: 5m 40s
# 3090:	learn: 0.9955930	test: 0.9949498	best: 0.9949498 (3090)	total: 1h 49m 36s	remaining: 5m 38s
# 3091:	learn: 0.9955932	test: 0.9949505	best: 0.9949505 (3091)	total: 1h 49m 38s	remaining: 5m 36s
# 3092:	learn: 0.9955936	test: 0.9949510	best: 0.9949510 (3092)	total: 1h 49m 40s	remaining: 5m 34s
# 3093:	learn: 0.9955939	test: 0.9949526	best: 0.9949526 (3093)	total: 1h 49m 42s	remaining: 5m 31s
# 3094:	learn: 0.9955942	test: 0.9949526	best: 0.9949526 (3093)	total: 1h 49m 45s	remaining: 5m 29s
# 3095:	learn: 0.9955944	test: 0.9949537	best: 0.9949537 (3095)	total: 1h 49m 47s	remaining: 5m 27s
# 3096:	learn: 0.9955947	test: 0.9949533	best: 0.9949537 (3095)	total: 1h 49m 49s	remaining: 5m 25s
# 3097:	learn: 0.9955949	test: 0.9949523	best: 0.9949537 (3095)	total: 1h 49m 51s	remaining: 5m 23s
# 3098:	learn: 0.9955953	test: 0.9949532	best: 0.9949537 (3095)	total: 1h 49m 53s	remaining: 5m 21s
# 3099:	learn: 0.9955956	test: 0.9949537	best: 0.9949537 (3099)	total: 1h 49m 55s	remaining: 5m 19s
# 3100:	learn: 0.9955960	test: 0.9949534	best: 0.9949537 (3099)	total: 1h 49m 57s	remaining: 5m 17s
# 3101:	learn: 0.9955963	test: 0.9949533	best: 0.9949537 (3099)	total: 1h 49m 59s	remaining: 5m 14s
# 3102:	learn: 0.9955966	test: 0.9949532	best: 0.9949537 (3099)	total: 1h 50m 1s	remaining: 5m 12s
# 3103:	learn: 0.9955968	test: 0.9949541	best: 0.9949541 (3103)	total: 1h 50m 4s	remaining: 5m 10s
# 3104:	learn: 0.9955971	test: 0.9949553	best: 0.9949553 (3104)	total: 1h 50m 6s	remaining: 5m 8s
# 3105:	learn: 0.9955974	test: 0.9949560	best: 0.9949560 (3105)	total: 1h 50m 8s	remaining: 5m 6s
# 3106:	learn: 0.9955977	test: 0.9949563	best: 0.9949563 (3106)	total: 1h 50m 10s	remaining: 5m 4s
# 3107:	learn: 0.9955980	test: 0.9949561	best: 0.9949563 (3106)	total: 1h 50m 12s	remaining: 5m 2s
# 3108:	learn: 0.9955989	test: 0.9949572	best: 0.9949572 (3108)	total: 1h 50m 15s	remaining: 5m
# 3109:	learn: 0.9955994	test: 0.9949570	best: 0.9949572 (3108)	total: 1h 50m 17s	remaining: 4m 57s
# 3110:	learn: 0.9955998	test: 0.9949577	best: 0.9949577 (3110)	total: 1h 50m 19s	remaining: 4m 55s
# 3111:	learn: 0.9956003	test: 0.9949587	best: 0.9949587 (3111)	total: 1h 50m 21s	remaining: 4m 53s
# 3112:	learn: 0.9956006	test: 0.9949588	best: 0.9949588 (3112)	total: 1h 50m 23s	remaining: 4m 51s
# 3113:	learn: 0.9956009	test: 0.9949594	best: 0.9949594 (3113)	total: 1h 50m 25s	remaining: 4m 49s
# 3114:	learn: 0.9956013	test: 0.9949602	best: 0.9949602 (3114)	total: 1h 50m 27s	remaining: 4m 47s
# 3115:	learn: 0.9956015	test: 0.9949601	best: 0.9949602 (3114)	total: 1h 50m 29s	remaining: 4m 45s
# 3116:	learn: 0.9956020	test: 0.9949596	best: 0.9949602 (3114)	total: 1h 50m 31s	remaining: 4m 42s
# 3117:	learn: 0.9956023	test: 0.9949594	best: 0.9949602 (3114)	total: 1h 50m 33s	remaining: 4m 40s
# 3118:	learn: 0.9956027	test: 0.9949606	best: 0.9949606 (3118)	total: 1h 50m 35s	remaining: 4m 38s
# 3119:	learn: 0.9956030	test: 0.9949602	best: 0.9949606 (3118)	total: 1h 50m 37s	remaining: 4m 36s
# 3120:	learn: 0.9956032	test: 0.9949616	best: 0.9949616 (3120)	total: 1h 50m 39s	remaining: 4m 34s
# 3121:	learn: 0.9956034	test: 0.9949620	best: 0.9949620 (3121)	total: 1h 50m 41s	remaining: 4m 32s
# 3122:	learn: 0.9956039	test: 0.9949627	best: 0.9949627 (3122)	total: 1h 50m 43s	remaining: 4m 30s
# 3123:	learn: 0.9956044	test: 0.9949630	best: 0.9949630 (3123)	total: 1h 50m 45s	remaining: 4m 28s
# 3124:	learn: 0.9956049	test: 0.9949636	best: 0.9949636 (3124)	total: 1h 50m 47s	remaining: 4m 25s
# 3125:	learn: 0.9956052	test: 0.9949637	best: 0.9949637 (3125)	total: 1h 50m 49s	remaining: 4m 23s
# 3126:	learn: 0.9956058	test: 0.9949675	best: 0.9949675 (3126)	total: 1h 50m 51s	remaining: 4m 21s
# 3127:	learn: 0.9956063	test: 0.9949691	best: 0.9949691 (3127)	total: 1h 50m 53s	remaining: 4m 19s
# 3128:	learn: 0.9956065	test: 0.9949694	best: 0.9949694 (3128)	total: 1h 50m 55s	remaining: 4m 17s
# 3129:	learn: 0.9956067	test: 0.9949696	best: 0.9949696 (3129)	total: 1h 50m 57s	remaining: 4m 15s
# 3130:	learn: 0.9956071	test: 0.9949706	best: 0.9949706 (3130)	total: 1h 50m 59s	remaining: 4m 13s
# 3131:	learn: 0.9956075	test: 0.9949706	best: 0.9949706 (3130)	total: 1h 51m 2s	remaining: 4m 10s
# 3132:	learn: 0.9956077	test: 0.9949702	best: 0.9949706 (3130)	total: 1h 51m 4s	remaining: 4m 8s
# 3133:	learn: 0.9956080	test: 0.9949712	best: 0.9949712 (3133)	total: 1h 51m 5s	remaining: 4m 6s
# 3134:	learn: 0.9956085	test: 0.9949713	best: 0.9949713 (3134)	total: 1h 51m 8s	remaining: 4m 4s
# 3135:	learn: 0.9956088	test: 0.9949720	best: 0.9949720 (3135)	total: 1h 51m 10s	remaining: 4m 2s
# 3136:	learn: 0.9956090	test: 0.9949721	best: 0.9949721 (3136)	total: 1h 51m 12s	remaining: 4m
# 3137:	learn: 0.9956094	test: 0.9949717	best: 0.9949721 (3136)	total: 1h 51m 14s	remaining: 3m 58s
# 3138:	learn: 0.9956097	test: 0.9949726	best: 0.9949726 (3138)	total: 1h 51m 16s	remaining: 3m 56s
# 3139:	learn: 0.9956101	test: 0.9949727	best: 0.9949727 (3139)	total: 1h 51m 18s	remaining: 3m 53s
# 3140:	learn: 0.9956103	test: 0.9949727	best: 0.9949727 (3139)	total: 1h 51m 20s	remaining: 3m 51s
# 3141:	learn: 0.9956106	test: 0.9949736	best: 0.9949736 (3141)	total: 1h 51m 22s	remaining: 3m 49s
# 3142:	learn: 0.9956109	test: 0.9949741	best: 0.9949741 (3142)	total: 1h 51m 25s	remaining: 3m 47s
# 3143:	learn: 0.9956112	test: 0.9949742	best: 0.9949742 (3143)	total: 1h 51m 27s	remaining: 3m 45s
# 3144:	learn: 0.9956116	test: 0.9949759	best: 0.9949759 (3144)	total: 1h 51m 29s	remaining: 3m 43s
# 3145:	learn: 0.9956119	test: 0.9949746	best: 0.9949759 (3144)	total: 1h 51m 31s	remaining: 3m 41s
# 3146:	learn: 0.9956122	test: 0.9949754	best: 0.9949759 (3144)	total: 1h 51m 33s	remaining: 3m 39s
# 3147:	learn: 0.9956125	test: 0.9949754	best: 0.9949759 (3144)	total: 1h 51m 35s	remaining: 3m 36s
# 3148:	learn: 0.9956128	test: 0.9949764	best: 0.9949764 (3148)	total: 1h 51m 37s	remaining: 3m 34s
# 3149:	learn: 0.9956132	test: 0.9949767	best: 0.9949767 (3149)	total: 1h 51m 40s	remaining: 3m 32s
# 3150:	learn: 0.9956137	test: 0.9949770	best: 0.9949770 (3150)	total: 1h 51m 42s	remaining: 3m 30s
# 3151:	learn: 0.9956141	test: 0.9949773	best: 0.9949773 (3151)	total: 1h 51m 44s	remaining: 3m 28s
# 3152:	learn: 0.9956144	test: 0.9949773	best: 0.9949773 (3152)	total: 1h 51m 46s	remaining: 3m 26s
# 3153:	learn: 0.9956145	test: 0.9949782	best: 0.9949782 (3153)	total: 1h 51m 48s	remaining: 3m 24s
# 3154:	learn: 0.9956149	test: 0.9949788	best: 0.9949788 (3154)	total: 1h 51m 50s	remaining: 3m 22s
# 3155:	learn: 0.9956152	test: 0.9949792	best: 0.9949792 (3155)	total: 1h 51m 52s	remaining: 3m 19s
# 3156:	learn: 0.9956155	test: 0.9949787	best: 0.9949792 (3155)	total: 1h 51m 54s	remaining: 3m 17s
# 3157:	learn: 0.9956158	test: 0.9949791	best: 0.9949792 (3155)	total: 1h 51m 56s	remaining: 3m 15s
# 3158:	learn: 0.9956162	test: 0.9949805	best: 0.9949805 (3158)	total: 1h 51m 59s	remaining: 3m 13s
# 3159:	learn: 0.9956166	test: 0.9949808	best: 0.9949808 (3159)	total: 1h 52m 1s	remaining: 3m 11s
# 3160:	learn: 0.9956170	test: 0.9949811	best: 0.9949811 (3160)	total: 1h 52m 3s	remaining: 3m 9s
# 3161:	learn: 0.9956173	test: 0.9949807	best: 0.9949811 (3160)	total: 1h 52m 5s	remaining: 3m 7s
# 3162:	learn: 0.9956175	test: 0.9949806	best: 0.9949811 (3160)	total: 1h 52m 7s	remaining: 3m 5s
# 3163:	learn: 0.9956178	test: 0.9949803	best: 0.9949811 (3160)	total: 1h 52m 9s	remaining: 3m 2s
# 3164:	learn: 0.9956181	test: 0.9949797	best: 0.9949811 (3160)	total: 1h 52m 11s	remaining: 3m
# 3165:	learn: 0.9956186	test: 0.9949805	best: 0.9949811 (3160)	total: 1h 52m 14s	remaining: 2m 58s
# 3166:	learn: 0.9956188	test: 0.9949805	best: 0.9949811 (3160)	total: 1h 52m 16s	remaining: 2m 56s
# 3167:	learn: 0.9956193	test: 0.9949809	best: 0.9949811 (3160)	total: 1h 52m 18s	remaining: 2m 54s
# 3168:	learn: 0.9956196	test: 0.9949816	best: 0.9949816 (3168)	total: 1h 52m 20s	remaining: 2m 52s
# 3169:	learn: 0.9956200	test: 0.9949829	best: 0.9949829 (3169)	total: 1h 52m 22s	remaining: 2m 50s
# 3170:	learn: 0.9956204	test: 0.9949831	best: 0.9949831 (3170)	total: 1h 52m 24s	remaining: 2m 48s
# 3171:	learn: 0.9956208	test: 0.9949838	best: 0.9949838 (3171)	total: 1h 52m 26s	remaining: 2m 45s
# 3172:	learn: 0.9956211	test: 0.9949843	best: 0.9949843 (3172)	total: 1h 52m 28s	remaining: 2m 43s
# 3173:	learn: 0.9956214	test: 0.9949850	best: 0.9949850 (3173)	total: 1h 52m 30s	remaining: 2m 41s
# 3174:	learn: 0.9956216	test: 0.9949850	best: 0.9949850 (3173)	total: 1h 52m 32s	remaining: 2m 39s
# 3175:	learn: 0.9956220	test: 0.9949861	best: 0.9949861 (3175)	total: 1h 52m 34s	remaining: 2m 37s
# 3176:	learn: 0.9956222	test: 0.9949865	best: 0.9949865 (3176)	total: 1h 52m 36s	remaining: 2m 35s
# 3177:	learn: 0.9956226	test: 0.9949859	best: 0.9949865 (3176)	total: 1h 52m 38s	remaining: 2m 33s
# 3178:	learn: 0.9956229	test: 0.9949858	best: 0.9949865 (3176)	total: 1h 52m 40s	remaining: 2m 30s
# 3179:	learn: 0.9956231	test: 0.9949857	best: 0.9949865 (3176)	total: 1h 52m 42s	remaining: 2m 28s
# 3180:	learn: 0.9956235	test: 0.9949864	best: 0.9949865 (3176)	total: 1h 52m 44s	remaining: 2m 26s
# 3181:	learn: 0.9956238	test: 0.9949871	best: 0.9949871 (3181)	total: 1h 52m 46s	remaining: 2m 24s
# 3182:	learn: 0.9956242	test: 0.9949874	best: 0.9949874 (3182)	total: 1h 52m 49s	remaining: 2m 22s
# 3183:	learn: 0.9956245	test: 0.9949867	best: 0.9949874 (3182)	total: 1h 52m 51s	remaining: 2m 20s
# 3184:	learn: 0.9956249	test: 0.9949863	best: 0.9949874 (3182)	total: 1h 52m 53s	remaining: 2m 18s
# 3185:	learn: 0.9956252	test: 0.9949860	best: 0.9949874 (3182)	total: 1h 52m 55s	remaining: 2m 16s
# 3186:	learn: 0.9956255	test: 0.9949846	best: 0.9949874 (3182)	total: 1h 52m 57s	remaining: 2m 13s
# 3187:	learn: 0.9956259	test: 0.9949843	best: 0.9949874 (3182)	total: 1h 52m 59s	remaining: 2m 11s
# 3188:	learn: 0.9956261	test: 0.9949843	best: 0.9949874 (3182)	total: 1h 53m 1s	remaining: 2m 9s
# 3189:	learn: 0.9956265	test: 0.9949837	best: 0.9949874 (3182)	total: 1h 53m 3s	remaining: 2m 7s
# 3190:	learn: 0.9956268	test: 0.9949846	best: 0.9949874 (3182)	total: 1h 53m 5s	remaining: 2m 5s
# 3191:	learn: 0.9956272	test: 0.9949850	best: 0.9949874 (3182)	total: 1h 53m 8s	remaining: 2m 3s
# 3192:	learn: 0.9956275	test: 0.9949852	best: 0.9949874 (3182)	total: 1h 53m 10s	remaining: 2m 1s
# 3193:	learn: 0.9956277	test: 0.9949854	best: 0.9949874 (3182)	total: 1h 53m 12s	remaining: 1m 59s
# 3194:	learn: 0.9956280	test: 0.9949857	best: 0.9949874 (3182)	total: 1h 53m 14s	remaining: 1m 56s
# 3195:	learn: 0.9956283	test: 0.9949863	best: 0.9949874 (3182)	total: 1h 53m 16s	remaining: 1m 54s
# 3196:	learn: 0.9956286	test: 0.9949864	best: 0.9949874 (3182)	total: 1h 53m 18s	remaining: 1m 52s
# 3197:	learn: 0.9956290	test: 0.9949869	best: 0.9949874 (3182)	total: 1h 53m 20s	remaining: 1m 50s
# 3198:	learn: 0.9956294	test: 0.9949867	best: 0.9949874 (3182)	total: 1h 53m 23s	remaining: 1m 48s
# 3199:	learn: 0.9956299	test: 0.9949866	best: 0.9949874 (3182)	total: 1h 53m 25s	remaining: 1m 46s
# 3200:	learn: 0.9956301	test: 0.9949869	best: 0.9949874 (3182)	total: 1h 53m 27s	remaining: 1m 44s
# 3201:	learn: 0.9956304	test: 0.9949868	best: 0.9949874 (3182)	total: 1h 53m 29s	remaining: 1m 42s
# 3202:	learn: 0.9956306	test: 0.9949865	best: 0.9949874 (3182)	total: 1h 53m 31s	remaining: 1m 39s
# 3203:	learn: 0.9956309	test: 0.9949862	best: 0.9949874 (3182)	total: 1h 53m 34s	remaining: 1m 37s
# 3204:	learn: 0.9956311	test: 0.9949862	best: 0.9949874 (3182)	total: 1h 53m 35s	remaining: 1m 35s
# 3205:	learn: 0.9956315	test: 0.9949863	best: 0.9949874 (3182)	total: 1h 53m 37s	remaining: 1m 33s
# 3206:	learn: 0.9956317	test: 0.9949869	best: 0.9949874 (3182)	total: 1h 53m 40s	remaining: 1m 31s
# 3207:	learn: 0.9956321	test: 0.9949871	best: 0.9949874 (3182)	total: 1h 53m 42s	remaining: 1m 29s
# 3208:	learn: 0.9956324	test: 0.9949874	best: 0.9949874 (3182)	total: 1h 53m 44s	remaining: 1m 27s
# 3209:	learn: 0.9956326	test: 0.9949877	best: 0.9949877 (3209)	total: 1h 53m 46s	remaining: 1m 25s
# 3210:	learn: 0.9956328	test: 0.9949881	best: 0.9949881 (3210)	total: 1h 53m 48s	remaining: 1m 22s
# 3211:	learn: 0.9956332	test: 0.9949887	best: 0.9949887 (3211)	total: 1h 53m 50s	remaining: 1m 20s
# 3212:	learn: 0.9956335	test: 0.9949901	best: 0.9949901 (3212)	total: 1h 53m 53s	remaining: 1m 18s
# 3213:	learn: 0.9956339	test: 0.9949894	best: 0.9949901 (3212)	total: 1h 53m 55s	remaining: 1m 16s
# 3214:	learn: 0.9956343	test: 0.9949904	best: 0.9949904 (3214)	total: 1h 53m 58s	remaining: 1m 14s
# 3215:	learn: 0.9956346	test: 0.9949910	best: 0.9949910 (3215)	total: 1h 53m 59s	remaining: 1m 12s
# 3216:	learn: 0.9956351	test: 0.9949909	best: 0.9949910 (3215)	total: 1h 54m 2s	remaining: 1m 10s
# 3217:	learn: 0.9956355	test: 0.9949909	best: 0.9949910 (3215)	total: 1h 54m 4s	remaining: 1m 8s
# 3218:	learn: 0.9956358	test: 0.9949909	best: 0.9949910 (3215)	total: 1h 54m 6s	remaining: 1m 5s
# 3219:	learn: 0.9956362	test: 0.9949912	best: 0.9949912 (3219)	total: 1h 54m 8s	remaining: 1m 3s
# 3220:	learn: 0.9956365	test: 0.9949944	best: 0.9949944 (3220)	total: 1h 54m 10s	remaining: 1m 1s
# 3221:	learn: 0.9956370	test: 0.9949921	best: 0.9949944 (3220)	total: 1h 54m 12s	remaining: 59.6s
# 3222:	learn: 0.9956374	test: 0.9949921	best: 0.9949944 (3220)	total: 1h 54m 14s	remaining: 57.4s
# 3223:	learn: 0.9956378	test: 0.9949924	best: 0.9949944 (3220)	total: 1h 54m 17s	remaining: 55.3s
# 3224:	learn: 0.9956381	test: 0.9949931	best: 0.9949944 (3220)	total: 1h 54m 19s	remaining: 53.2s
# 3225:	learn: 0.9956384	test: 0.9949941	best: 0.9949944 (3220)	total: 1h 54m 21s	remaining: 51s
# 3226:	learn: 0.9956391	test: 0.9950010	best: 0.9950010 (3226)	total: 1h 54m 23s	remaining: 48.9s
# 3227:	learn: 0.9956393	test: 0.9950020	best: 0.9950020 (3227)	total: 1h 54m 26s	remaining: 46.8s
# 3228:	learn: 0.9956396	test: 0.9950001	best: 0.9950020 (3227)	total: 1h 54m 28s	remaining: 44.7s
# 3229:	learn: 0.9956399	test: 0.9950005	best: 0.9950020 (3227)	total: 1h 54m 30s	remaining: 42.5s
# 3230:	learn: 0.9956402	test: 0.9950007	best: 0.9950020 (3227)	total: 1h 54m 32s	remaining: 40.4s
# 3231:	learn: 0.9956406	test: 0.9950012	best: 0.9950020 (3227)	total: 1h 54m 34s	remaining: 38.3s
# 3232:	learn: 0.9956412	test: 0.9950017	best: 0.9950020 (3227)	total: 1h 54m 36s	remaining: 36.2s
# 3233:	learn: 0.9956415	test: 0.9950020	best: 0.9950020 (3227)	total: 1h 54m 39s	remaining: 34s
# 3234:	learn: 0.9956418	test: 0.9950035	best: 0.9950035 (3234)	total: 1h 54m 41s	remaining: 31.9s
# 3235:	learn: 0.9956420	test: 0.9950035	best: 0.9950035 (3234)	total: 1h 54m 43s	remaining: 29.8s
# 3236:	learn: 0.9956424	test: 0.9950038	best: 0.9950038 (3236)	total: 1h 54m 45s	remaining: 27.7s
# 3237:	learn: 0.9956427	test: 0.9950044	best: 0.9950044 (3237)	total: 1h 54m 47s	remaining: 25.5s
# 3238:	learn: 0.9956430	test: 0.9950052	best: 0.9950052 (3238)	total: 1h 54m 49s	remaining: 23.4s
# 3239:	learn: 0.9956433	test: 0.9950075	best: 0.9950075 (3239)	total: 1h 54m 51s	remaining: 21.3s
# 3240:	learn: 0.9956437	test: 0.9950077	best: 0.9950077 (3240)	total: 1h 54m 53s	remaining: 19.1s
# 3241:	learn: 0.9956441	test: 0.9950073	best: 0.9950077 (3240)	total: 1h 54m 55s	remaining: 17s
# 3242:	learn: 0.9956445	test: 0.9950076	best: 0.9950077 (3240)	total: 1h 54m 57s	remaining: 14.9s
# 3243:	learn: 0.9956448	test: 0.9950083	best: 0.9950083 (3243)	total: 1h 55m	remaining: 12.8s
# 3244:	learn: 0.9956450	test: 0.9950086	best: 0.9950086 (3244)	total: 1h 55m 2s	remaining: 10.6s
# 3245:	learn: 0.9956454	test: 0.9950093	best: 0.9950093 (3245)	total: 1h 55m 3s	remaining: 8.51s
# 3246:	learn: 0.9956458	test: 0.9950097	best: 0.9950097 (3246)	total: 1h 55m 6s	remaining: 6.38s
# 3247:	learn: 0.9956460	test: 0.9950103	best: 0.9950103 (3247)	total: 1h 55m 8s	remaining: 4.25s
# 3248:	learn: 0.9956463	test: 0.9950120	best: 0.9950120 (3248)	total: 1h 55m 11s	remaining: 2.13s
# 3249:	learn: 0.9956465	test: 0.9950126	best: 0.9950126 (3249)	total: 1h 55m 13s	remaining: 0us
#
# bestTest = 0.9950125589
# bestIteration = 3249
# {'learn': {'R2': 0.9956465239813657, 'RMSE': 2.305507542767881},
#  'validation': {'R2': 0.9950125588682586, 'RMSE': 2.3623564377512096}}

# %%
del X_valid
del y_valid

# %%
feature_stuff = dict(zip(cat.feature_names_, cat.feature_importances_))
feature_stuff
# Out:
# {'atom_0': 0.0,
#  'atom_0_couples_count': 0.34276195894776856,
#  'atom_1': 0.19108765043782172,
#  'atom_1_couples_count': 0.7850655084760128,
#  'atom_index_0': 0.022533846612625197,
#  'atom_index_1': 0.11998903151140974,
#  'cos_0': 0.006817662278895138,
#  'cos_0_1': 0.006185575310408398,
#  'cos_1': 0.006070545360329384,
#  'dist': 15.88942012081377,
#  'dist_to_type_mean': 2.325944849632149,
#  'dist_x': 0.003788426262700007,
#  'dist_y': 0.009712265692647137,
#  'dist_z': 0.010267680202549166,
#  'distance_0': 0.002989762520851155,
#  'distance_1': 0.02583775207518611,
#  'min_distance_0': 0.8477816589379646,
#  'min_distance_1': 0.5874561070746659,
#  'molecule_atom_1_dist_std': 0.014877679716117694,
#  'molecule_atom_1_dist_std_diff': 0.11308465883041618,
#  'molecule_atom_index_0_dist_max': 0.18697083924421973,
#  'molecule_atom_index_0_dist_max_div': 0.24036601895448081,
#  'molecule_atom_index_0_dist_mean': 0.12835459685508763,
#  'molecule_atom_index_0_dist_mean_div': 0.08362599718213078,
#  'molecule_atom_index_0_dist_min': 1.0658349379803682,
#  'molecule_atom_index_0_dist_min_div': 0.27927035194753747,
#  'molecule_atom_index_0_dist_std': 0.24480175285881414,
#  'molecule_atom_index_0_dist_std_diff': 1.6247272955246697,
#  'molecule_atom_index_0_dist_std_div': 0.36226038534184757,
#  'molecule_atom_index_0_x_1_std': 0.005972303967177084,
#  'molecule_atom_index_0_y_1_std': 0.023878493437597858,
#  'molecule_atom_index_0_z_1_std': 0.019518292053819334,
#  'molecule_atom_index_1_dist_max': 0.07416552304388854,
#  'molecule_atom_index_1_dist_max_div': 0.07505957901977331,
#  'molecule_atom_index_1_dist_mean': 0.20010964733325015,
#  'molecule_atom_index_1_dist_mean_div': 0.33180611022123113,
#  'molecule_atom_index_1_dist_min': 0.26208928900132455,
#  'molecule_atom_index_1_dist_min_div': 0.07862128613832656,
#  'molecule_atom_index_1_dist_std': 0.030696938164041884,
#  'molecule_atom_index_1_dist_std_diff': 0.21644707049351392,
#  'molecule_atom_index_1_dist_std_div': 0.08647616855541963,
#  'molecule_couples': 0.16187212669028817,
#  'molecule_dist_max': 0.013872623081946207,
#  'molecule_dist_mean': 0.015150549964549651,
#  'molecule_dist_mean_div': 0.12698045395950366,
#  'molecule_dist_min': 0.014858991324553206,
#  'molecule_type_dist_max': 0.31002779849150336,
#  'molecule_type_dist_mean': 0.1831213831559274,
#  'molecule_type_dist_mean_div': 0.4496231903251918,
#  'molecule_type_dist_min': 0.0791766111130483,
#  'molecule_type_dist_std': 0.1893007817355529,
#  'molecule_type_dist_std_diff': 0.40670143398369585,
#  'type': 71.07763429206703,
#  'x_0': 0.006021418441126946,
#  'x_1': 0.0010318761397912159,
#  'y_0': 0.017267364354670016,
#  'y_1': 0.010697426058461313,
#  'z_0': 0.0025790001890378363,
#  'z_1': 0.0013570609113294195}

# %%
cat.save_model('Predicting_Molecular_Properties_Catboost_Final.hdf5')

# %%
Y_pred = cat.predict(test)
del test
len(Y_pred)
# Out:
# 2505542

# %%
sample_sub.head()
# Out:
#         id  scalar_coupling_constant
# 0  4658147                         0
# 1  4658148                         0
# 2  4658149                         0
# 3  4658150                         0
# 4  4658151                         0

# %%
sample_sub.scalar_coupling_constant = Y_pred
del Y_pred

# %%
sample_sub.head()
# Out:
#         id  scalar_coupling_constant
# 0  4658147                 12.103838
# 1  4658148                179.321172
# 2  4658149                  6.202224
# 3  4658150                181.443416
# 4  4658151                  9.499162

# %%
len(sample_sub)
# Out:
# 2505542

# %%
sample_sub.isnull().sum()
# Out:
# id                          0
# scalar_coupling_constant    0
# dtype: int64

# %%
sample_sub.to_csv('Predicting_Molecular_Properties_1.gz', index=False, compression='gzip')

# %%
from google.colab import files
files.download('Predicting_Molecular_Properties_1.gz')

# %%
# make a predictor that predicts values of scalar_coupling dataframe - make predictions on test set, use that as more data for the ensemble - scalar coupling and train datasets match
# or use MICE to fill in missing data on test set using scalar_coupling with training set
# predict potential energy and mulliken charges and other features
# use separate models for each type
# ensemble with random forest and extra trees and more catboosts - maybe trained on part of full data

# THINGS TO PREDICT FOR TESTING SET:
# dipole_moments, potential_energy, mulliken_charges, fc, sd, pso, dso
